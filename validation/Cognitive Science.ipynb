# %%
# %load_ext autoreload
# %autoreload 1

# %%
import pandas as pd
import numpy as np

import sys 
sys.path.append("..") 
import os
# %aimport preprocessing
# %aimport utils
# %aimport p2v

from sklearn.metrics.pairwise import cosine_similarity
from scipy.stats import kendalltau
from collections import defaultdict

from utils import prinT

import seaborn as sns
from matplotlib import pyplot as plt

pd.options.display.max_columns = None
pd.set_option('max_colwidth', None)
pd.set_option('display.max_rows', None)

# %%
model = p2v.P2V()
d=100
w=10
# Out:
# 2024-01-07 17:24:49 -- start loading Mag_venue_info_df
# 2024-01-07 17:24:49 -- finish.
# 2024-01-07 17:24:49 -- start loading labeled_journal_info_df
# 2024-01-07 17:24:49 -- finish.

# %% [markdown]
# **tracking Cognitive Science**
#
# Cognitive Science
# 78735424

# %%
def default_value():
    return 0


def count_paper_num_for_subarea(VID):
    dict_list = []
    for i in range(len(model.start_year_list)-5, len(model.start_year_list)):
        start_year=model.start_year_list[i]
        end_year=model.end_year_list[i]
        prinT("start searching in %s to %s" %(start_year, end_year))

        model.load_paper_df(full_load=False, start_year=start_year, end_year=end_year)
        model.load_ref_df(full_load=False, start_year=start_year, end_year=end_year)
        VID_labeled = model.load_VID_labeled(start_year, end_year, d, w)
        VID_labeled_df = pd.DataFrame(VID_labeled)
        VID_labeled_df.set_index('VID', inplace=True)

        journal_df = model.target_paper_df[model.target_paper_df.VenueID == VID]
        journal_ref_df = pd.merge(journal_df, model.target_ref_df, left_on='PaperID', right_on='PaperID')
        journal_ref_df = pd.merge(journal_ref_df, model.target_paper_df, left_on='PaperReferenceID', right_on='PaperID')
        journal_ref_df.drop(columns=['PaperReferenceID'], inplace=True)
        journal_ref_df = pd.merge(journal_ref_df, VID_labeled_df, left_on='VenueID_y', right_index=True)

        journal_ref_df.drop(journal_ref_df[
                            (journal_ref_df['subarea_label'].str.contains('General'))|
                            (journal_ref_df['subarea_label'].str.contains('miscellaneous'))|
                            (journal_ref_df['subarea_label']=='Multidisciplinary')].index, 
                            inplace=True)

        subarea_paper_count = defaultdict(default_value)
        for row in journal_ref_df.groupby(['PaperID_x'])['subarea_label'].agg(pd.Series.mode):
            if type(row) == str:
                subarea_paper_count[row] = subarea_paper_count[row] + 1
            if type(row) == np.ndarray:
                subarea_num = len(row)
                for subarea in row:
                    subarea_paper_count[subarea] = subarea_paper_count[subarea] + 1/subarea_num
        dict_list.append(dict(subarea_paper_count))
    count_df = pd.DataFrame(dict_list).T
    count_df.columns = ['1970s', '1980s', '1990s', '2000s', '2010s']
    count_df['sum']=count_df.sum(axis=1)
    count_df.reset_index(inplace=True)
    count_df = count_df.sort_values("sum", ascending=False)
    count_df_up = count_df.iloc[:7]
    count_df_full = pd.concat([count_df_up, pd.DataFrame({'index': 'others', 
                                                          '1970s': count_df['1970s'].iloc[10:].sum(), 
                                                          '1980s': count_df['1980s'].iloc[10:].sum(), 
                                                          '1990s': count_df['1990s'].iloc[10:].sum(), 
                                                          '2000s': count_df['2000s'].iloc[10:].sum(), 
                                                          '2010s': count_df['2010s'].iloc[10:].sum(), 
                                                          'sum': count_df['sum'].iloc[7:].sum()}, 
                                                         index=[0])], 
                              ignore_index=True)
    count_df_full['1970s'] = (count_df_full['1970s']/count_df_full['1970s'].sum()) * 100
    count_df_full['1980s'] = (count_df_full['1980s']/count_df_full['1980s'].sum()) * 100
    count_df_full['1990s'] = (count_df_full['1990s']/count_df_full['1990s'].sum()) * 100
    count_df_full['2000s'] = (count_df_full['2000s']/count_df_full['2000s'].sum()) * 100
    count_df_full['2010s'] = (count_df_full['2010s']/count_df_full['2010s'].sum()) * 100
    count_df_full.set_index('index', inplace=True)
    count_df_full.index.rename('decade', inplace=True)
    count_df_full.drop('sum', axis=1, inplace=True)

    return count_df_full.T


def cal_subarea_avg_cs(target_VID: int):
    cs_data = []
    for i in range(len(model.start_year_list)-5, len(model.start_year_list)):
        model.load_wv(model.start_year_list[i], model.end_year_list[i], d, w)
        target_journal_vector = model.wv.get_vector(target_VID, norm=True)
        full_vector_list = model.wv.get_normed_vectors()

        VID_labeled = model.load_VID_labeled(model.start_year_list[i], model.end_year_list[i], d, w)
        label_list = VID_labeled['subarea_label']
        labeled_VID_list = VID_labeled['VID']
        labeled_vector_list = np.stack([model.wv.get_vector(VID, norm=True) for VID in labeled_VID_list])

        single_decade_data = {}
        subareas = list(set(label_list))
        for subarea in subareas:
            single_subarea_idx_list = [idx for idx, label in list(enumerate(label_list)) if label == subarea]
            single_subarea_cs = cosine_similarity(target_journal_vector.reshape(1, -1), labeled_vector_list[single_subarea_idx_list])
            general_cs = cosine_similarity(target_journal_vector.reshape(1, -1), full_vector_list)
            
            single_decade_data[subarea] = np.mean((single_subarea_cs))/np.mean(general_cs)
        cs_data.append(single_decade_data)
    cs_df = pd.DataFrame(cs_data).T
    cs_df.columns = ['1970s', '1980s', '1990s', '2000s', '2010s']
    cs_df['sum']=cs_df.sum(axis=1)
    cs_df = cs_df.sort_values("sum", ascending=False)
    cs_df.index.rename('decade', inplace=True)
    cs_df.drop('sum', axis=1, inplace=True)

    return cs_df.T

# %%
count_df = count_paper_num_for_subarea(78735424)
# Out:
# 2024-01-07 20:12:43 -- start searching in 1970 to 1979
# 2024-01-07 20:12:43 -- start loading 'paper_df'...
# 2024-01-07 20:12:43 -- finish.
# 2024-01-07 20:12:43 -- start loading 'ref_df'...
# 2024-01-07 20:12:44 -- finish.
# 2024-01-07 20:12:44 -- start loading VID_labeled...
# 2024-01-07 20:12:44 -- finish.
# 2024-01-07 20:12:46 -- start searching in 1980 to 1989
# 2024-01-07 20:12:46 -- start loading 'paper_df'...
# 2024-01-07 20:12:46 -- finish.
# 2024-01-07 20:12:46 -- start loading 'ref_df'...
# 2024-01-07 20:12:46 -- finish.
# 2024-01-07 20:12:46 -- start loading VID_labeled...
# 2024-01-07 20:12:46 -- finish.
# 2024-01-07 20:12:49 -- start searching in 1990 to 1999
# 2024-01-07 20:12:49 -- start loading 'paper_df'...
# 2024-01-07 20:12:50 -- finish.
# 2024-01-07 20:12:50 -- start loading 'ref_df'...
# 2024-01-07 20:12:51 -- finish.
# 2024-01-07 20:12:51 -- start loading VID_labeled...
# 2024-01-07 20:12:51 -- finish.
# 2024-01-07 20:12:57 -- start searching in 2000 to 2009
# 2024-01-07 20:12:57 -- start loading 'paper_df'...
# 2024-01-07 20:12:57 -- finish.
# 2024-01-07 20:12:57 -- start loading 'ref_df'...
# 2024-01-07 20:13:00 -- finish.
# 2024-01-07 20:13:00 -- start loading VID_labeled...
# 2024-01-07 20:13:00 -- finish.
# 2024-01-07 20:13:13 -- start searching in 2010 to 2021
# 2024-01-07 20:13:13 -- start loading 'paper_df'...
# 2024-01-07 20:13:13 -- finish.
# 2024-01-07 20:13:13 -- start loading 'ref_df'...
# 2024-01-07 20:13:22 -- finish.
# 2024-01-07 20:13:22 -- start loading VID_labeled...
# 2024-01-07 20:13:22 -- finish.

# %%
count_df
# Out:
# decade  Experimental and Cognitive Psychology  Linguistics and Language  \
# 1970s                                9.868421                 42.763158
# 1980s                               17.509025                 19.795427
# 1990s                               27.258567                 11.682243
# 2000s                               62.333545                 12.623426
# 2010s                               63.460839                  9.653007
#
# decade  Developmental and Educational Psychology  Artificial Intelligence  \
# 1970s                                        NaN                31.359649
# 1980s                                   0.902527                44.524669
# 1990s                                   1.401869                36.033229
# 2000s                                   4.982335                 2.047287
# 2010s                                   6.927049                 1.436302
#
# decade  Cognitive Neuroscience  Education  Philosophy     others
# 1970s                      NaN   4.824561    4.166667   7.017544
# 1980s                      NaN   4.392298    4.211793   8.664260
# 1990s                 2.492212   7.788162    2.699896  10.643821
# 2000s                 3.940574   2.989401    2.137875   8.945557
# 2010s                 3.623182   3.154329    2.451669   9.293622

# %%
cs_df = cal_subarea_avg_cs(78735424)
# Out:
# 2024-01-07 20:14:49 -- start loading word vectors...
# 2024-01-07 20:14:49 -- word vectors loaded, and its shape is: (5686, 100)
# 2024-01-07 20:14:49 -- start loading VID_labeled...
# 2024-01-07 20:14:49 -- finish.
# 2024-01-07 20:14:50 -- start loading word vectors...
# 2024-01-07 20:14:50 -- word vectors loaded, and its shape is: (9337, 100)
# 2024-01-07 20:14:50 -- start loading VID_labeled...
# 2024-01-07 20:14:50 -- finish.
# 2024-01-07 20:14:51 -- start loading word vectors...
# 2024-01-07 20:14:51 -- word vectors loaded, and its shape is: (15019, 100)
# 2024-01-07 20:14:51 -- start loading VID_labeled...
# 2024-01-07 20:14:51 -- finish.
# 2024-01-07 20:14:53 -- start loading word vectors...
# 2024-01-07 20:14:53 -- word vectors loaded, and its shape is: (27460, 100)
# 2024-01-07 20:14:53 -- start loading VID_labeled...
# 2024-01-07 20:14:53 -- finish.
# 2024-01-07 20:14:56 -- start loading word vectors...
# 2024-01-07 20:14:56 -- word vectors loaded, and its shape is: (37594, 100)
# 2024-01-07 20:14:56 -- start loading VID_labeled...
# 2024-01-07 20:14:57 -- finish.

# %%
cs_df
# Out:
# decade  Experimental and Cognitive Psychology  Linguistics and Language  \
# 1970s                                1.777167                  2.008691
# 1980s                                1.866354                  1.951528
# 1990s                                1.897475                  1.973581
# 2000s                                2.419747                  1.998145
# 2010s                                2.376287                  2.048199
#
# decade  Artificial Intelligence  Language and Linguistics  \
# 1970s                  2.209880                  1.796626
# 1980s                  2.409315                  1.803078
# 1990s                  2.085114                  1.637660
# 2000s                  1.626333                  2.069809
# 2010s                  1.601277                  1.842573
#
# decade  Psychology (miscellaneous)  Philosophy  General Psychology     Music  \
# 1970s                     1.850787    1.770452            1.512200  1.876002
# 1980s                     2.028556    1.663993            1.555005  1.526707
# 1990s                     1.572004    1.661376            1.659569  1.513034
# 2000s                     1.801966    1.728018            1.882992  1.751998
# 2010s                     1.734447    1.773574            1.804481  1.570020
#
# decade  Social Psychology  Education  \
# 1970s            1.563341   1.630551
# 1980s            1.515319   1.677936
# 1990s            1.521774   1.563053
# 2000s            1.810933   1.655353
# 2010s            1.754802   1.581216
#
# decade  Developmental and Educational Psychology  Information Systems  \
# 1970s                                   1.510090             1.712109
# 1980s                                   1.563760             1.829016
# 1990s                                   1.532642             1.630368
# 2000s                                   1.731329             1.393454
# 2010s                                   1.718497             1.376454
#
# decade  Human-Computer Interaction  \
# 1970s                          NaN
# 1980s                     2.152300
# 1990s                     1.929450
# 2000s                     2.056612
# 2010s                     1.747074
#
# decade  Computer Graphics and Computer-Aided Design  Software  \
# 1970s                                      1.808629  1.908810
# 1980s                                      1.565344  1.739837
# 1990s                                      1.468683  1.500718
# 2000s                                      1.522131  1.368627
# 2010s                                      1.447396  1.280428
#
# decade  Computational Theory and Mathematics  Control and Optimization  \
# 1970s                               2.333645                  1.629353
# 1980s                               1.520369                  2.657241
# 1990s                               1.418258                  1.450534
# 2000s                               1.265785                  0.950462
# 2010s                               1.237340                  1.071565
#
# decade     Logic  Neuropsychology and Physiological Psychology  \
# 1970s   1.634522                                      1.562290
# 1980s   1.440644                                      1.280393
# 1990s   1.470633                                      1.375720
# 2000s   1.629601                                      1.780179
# 2010s   1.581045                                      1.728077
#
# decade  Cognitive Neuroscience  Human Factors and Ergonomics  Communication  \
# 1970s                      NaN                      1.522465       1.622346
# 1980s                 2.052773                      1.512502       1.542800
# 1990s                 1.770002                      1.411350       1.281196
# 2000s                 2.016374                      1.747661       1.545594
# 2010s                 1.882933                      1.381385       1.535062
#
# decade  General Computer Science  Library and Information Sciences  \
# 1970s                   1.694975                          1.706905
# 1980s                   1.546267                          1.644700
# 1990s                   1.455150                          1.478605
# 2000s                   1.375933                          1.309981
# 2010s                   1.316328                          1.214355
#
# decade  Computer Science Applications  Literature and Literary Theory  \
# 1970s                        1.615665                        1.638090
# 1980s                        1.678140                        1.405729
# 1990s                        1.516106                        1.234235
# 2000s                        1.268081                        1.450743
# 2010s                        1.259851                        1.588191
#
# decade  Applied Psychology  Classics  Speech and Hearing  \
# 1970s             1.502219  1.402158            1.494682
# 1980s             1.403470  1.270168            1.433803
# 1990s             1.439312  1.320219            1.466969
# 2000s             1.541596  1.677515            1.470559
# 2010s             1.427439  1.569375            1.369823
#
# decade  Theoretical Computer Science  Accounting  \
# 1970s                       1.660400    1.620247
# 1980s                       1.581173    1.528335
# 1990s                       1.344664    1.461530
# 2000s                       1.300735    1.223399
# 2010s                       1.337989    1.359672
#
# decade  Computer Networks and Communications  Visual Arts and Performing Arts  \
# 1970s                               1.761542                         1.558289
# 1980s                               1.471411                         1.427300
# 1990s                               1.426433                         1.221657
# 2000s                               1.275149                         1.455736
# 2010s                               1.251688                         1.459931
#
# decade  General Arts and Humanities  Museology  \
# 1970s                      1.425126   1.827487
# 1980s                      1.404388   1.444267
# 1990s                      1.312172   1.104625
# 2000s                      1.464040   1.294037
# 2010s                      1.514633   1.438841
#
# decade  Arts and Humanities (miscellaneous)  Religious Studies  \
# 1970s                              1.311566           1.427972
# 1980s                              1.448910           1.284102
# 1990s                              1.451580           1.302102
# 2000s                              1.401073           1.409932
# 2010s                              1.413804           1.559225
#
# decade  Organizational Behavior and Human Resource Management  \
# 1970s                                                1.438278
# 1980s                                                1.199721
# 1990s                                                1.378776
# 2000s                                                1.444726
# 2010s                                                1.374166
#
# decade  Behavioral Neuroscience  Signal Processing  Strategy and Management  \
# 1970s                  1.336849           1.896265                 1.388743
# 1980s                  1.274091           1.326859                 1.338626
# 1990s                  1.176970           1.280526                 1.478565
# 2000s                  1.719425           0.971819                 1.306735
# 2010s                  1.312938           1.317192                 1.236974
#
# decade  Cultural Studies  Clinical Psychology  \
# 1970s           1.398471             1.397094
# 1980s           1.381764             1.306042
# 1990s           1.198194             1.267439
# 2000s           1.352479             1.341873
# 2010s           1.379193             1.382777
#
# decade  Control and Systems Engineering  \
# 1970s                          1.236763
# 1980s                          1.416535
# 1990s                          1.563546
# 2000s                          1.174509
# 2010s                          1.189519
#
# decade  Business, Management and Accounting (miscellaneous)  Marketing  \
# 1970s                                              1.546903   1.294519
# 1980s                                              1.238467   1.326785
# 1990s                                              1.315631   1.283395
# 2000s                                              1.266624   1.228548
# 2010s                                              1.211605   1.326900
#
# decade  General Social Sciences  Architecture  Occupational Therapy  \
# 1970s                  1.409373      1.312727              1.278140
# 1980s                  1.267511      1.272371              1.109833
# 1990s                  1.144899      1.362484              1.297341
# 2000s                  1.295594      1.305236              1.592850
# 2010s                  1.340147      1.203421              1.123994
#
# decade  Sensory Systems   Finance  Business and International Management  \
# 1970s          1.190281  1.351864                               1.349615
# 1980s          1.034131  1.275348                               1.229971
# 1990s          1.113677  1.333326                               1.322369
# 2000s          1.438923  1.071663                               1.176493
# 2010s          1.602439  1.336895                               1.212408
#
# decade  Tourism, Leisure and Hospitality Management  \
# 1970s                                      1.507471
# 1980s                                      1.162816
# 1990s                                      1.280233
# 2000s                                      1.107458
# 2010s                                      1.168638
#
# decade  General Business, Management and Accounting  Anthropology  \
# 1970s                                      1.164512      1.225801
# 1980s                                      1.310643      1.295901
# 1990s                                      1.263335      1.111048
# 2000s                                      1.249472      1.319615
# 2010s                                      1.208219      1.241925
#
# decade  Computers in Earth Sciences  \
# 1970s                      1.277764
# 1980s                      1.339782
# 1990s                      1.182290
# 2000s                      1.141425
# 2010s                      1.251732
#
# decade  Management Science and Operations Research  \
# 1970s                                     1.275050
# 1980s                                     1.401028
# 1990s                                     1.293719
# 2000s                                     1.157643
# 2010s                                     1.029508
#
# decade  Social Sciences (miscellaneous)  History and Philosophy of Science  \
# 1970s                          1.246943                           1.304062
# 1980s                          1.129820                           1.285587
# 1990s                          1.218833                           1.038580
# 2000s                          1.201337                           1.201932
# 2010s                          1.322623                           1.275819
#
# decade  Computational Mathematics  Industrial and Manufacturing Engineering  \
# 1970s                    1.548178                                  1.365639
# 1980s                    1.319614                                  1.556586
# 1990s                    1.032604                                  1.222720
# 2000s                    1.105410                                  1.052859
# 2010s                    1.063616                                  0.797669
#
# decade  Sociology and Political Science  Hardware and Architecture  \
# 1970s                          1.200558                        NaN
# 1980s                          1.124773                   1.827118
# 1990s                          1.092718                   1.603197
# 2000s                          1.225364                   1.250894
# 2010s                          1.349040                   1.273148
#
# decade  Archeology (arts and humanities)  General Neuroscience  \
# 1970s                           1.191128              0.946954
# 1980s                           1.254530              1.071041
# 1990s                           1.060872              1.036697
# 2000s                           1.270998              1.439679
# 2010s                           1.167603              1.414532
#
# decade  Health Informatics  Gender Studies  Transportation  \
# 1970s             1.410311        0.892940        1.163731
# 1980s             1.281572        1.377159        1.178872
# 1990s             1.338577        1.119940        1.198279
# 2000s             0.939462        1.203249        1.159210
# 2010s             0.931889        1.280649        1.110825
#
# decade  Psychiatric Mental Health   History  Rehabilitation  Archeology  \
# 1970s                    1.081723  1.196806        1.210647    1.005581
# 1980s                    1.187869  1.068019        1.210532    1.172024
# 1990s                    1.263614  1.004083        1.091790    0.983786
# 2000s                    1.178515  1.200324        1.225238    1.323069
# 2010s                    1.085753  1.326886        1.048523    1.278755
#
# decade  Information Systems and Management  Ecological Modeling       Law  \
# 1970s                             2.009075             1.026148  1.107467
# 1980s                                  NaN             1.109365  0.993499
# 1990s                             1.179372             1.098677  1.114162
# 2000s                             1.290720             1.185569  1.107106
# 2010s                             1.281330             1.197690  1.283988
#
# decade  Economics, Econometrics and Finance (miscellaneous)  \
# 1970s                                              0.710070
# 1980s                                              0.996676
# 1990s                                              1.288638
# 2000s                                              1.185035
# 2010s                                              1.361172
#
# decade  Modeling and Simulation  \
# 1970s                  1.150614
# 1980s                  1.158643
# 1990s                  1.128543
# 2000s                  1.029462
# 2010s                  1.024237
#
# decade  Physical Therapy, Sports Therapy and Rehabilitation  \
# 1970s                                              1.031392
# 1980s                                              1.115767
# 1990s                                              1.121503
# 2000s                                              1.174149
# 2010s                                              1.030869
#
# decade  Economics and Econometrics  Psychiatry and Mental Health  \
# 1970s                     1.036443                      1.118694
# 1980s                     1.012321                      1.027868
# 1990s                     1.106724                      1.033547
# 2000s                     1.081737                      1.109802
# 2010s                     1.211670                      1.147249
#
# decade  Management of Technology and Innovation  \
# 1970s                                  1.017637
# 1980s                                  1.016732
# 1990s                                  1.221252
# 2000s                                  1.033374
# 2010s                                  1.142267
#
# decade  General Economics, Econometrics and Finance  \
# 1970s                                      1.073999
# 1980s                                      0.977725
# 1990s                                      1.064055
# 2000s                                      1.106673
# 2010s                                      1.180424
#
# decade  Political Science and International Relations  \
# 1970s                                        1.121351
# 1980s                                        0.932094
# 1990s                                        0.955662
# 2000s                                        1.098335
# 2010s                                        1.287365
#
# decade  Nature and Landscape Conservation  Algebra and Number Theory  \
# 1970s                            1.096040                   1.245376
# 1980s                            1.195235                   0.994110
# 1990s                            0.826977                   0.902328
# 2000s                            1.233528                   1.126635
# 2010s                            1.029420                   1.107263
#
# decade  Public Administration  Electrical and Electronic Engineering  \
# 1970s                1.181748                               1.198582
# 1980s                0.986316                               1.128493
# 1990s                0.962766                               1.122738
# 2000s                1.016882                               0.957634
# 2010s                1.219716                               0.925692
#
# decade  Discrete Mathematics and Combinatorics  Applied Mathematics  \
# 1970s                                 1.292413             1.202421
# 1980s                                 0.947837             1.077125
# 1990s                                 0.900854             1.032088
# 2000s                                 1.125687             0.997730
# 2010s                                 1.053333             1.008587
#
# decade  Computer Vision and Pattern Recognition  Geometry and Topology  \
# 1970s                                       NaN               1.119522
# 1980s                                  1.184800               0.968344
# 1990s                                  1.511198               0.919110
# 2000s                                  1.353318               1.087699
# 2010s                                  1.258103               1.209298
#
# decade  Aerospace Engineering  Statistical and Nonlinear Physics  \
# 1970s                1.001934                           0.770592
# 1980s                0.966943                           1.092232
# 1990s                1.210809                           1.054121
# 2000s                1.129380                           1.076218
# 2010s                0.989162                           1.302841
#
# decade  Leadership and Management  General Nursing  General Mathematics  \
# 1970s                    1.064978         1.029056             1.126633
# 1980s                    0.972563         0.984491             0.955528
# 1990s                    1.077261         1.209166             0.933770
# 2000s                    1.095389         1.046648             1.094863
# 2010s                    1.082180         0.991630             1.137788
#
# decade  Health (social science)  Analysis  Biological Psychiatry  \
# 1970s                  0.934719  1.106410               1.045581
# 1980s                  1.087778  0.991180               0.894067
# 1990s                  1.099360  1.003956               0.738508
# 2000s                  1.015263  1.034624               1.168257
# 2010s                  1.109848  1.108536               1.393203
#
# decade  Management Information Systems  Neuroscience (miscellaneous)  \
# 1970s                              NaN                           NaN
# 1980s                         1.429791                           NaN
# 1990s                         1.309608                      1.865098
# 2000s                         1.279386                      1.765926
# 2010s                         1.206916                      1.584987
#
# decade  Astronomy and Astrophysics  Acoustics and Ultrasonics  \
# 1970s                     1.130348                   0.762916
# 1980s                     1.073254                   0.889846
# 1990s                     0.788623                   1.268702
# 2000s                     1.144915                   1.176026
# 2010s                     1.064561                   1.096287
#
# decade  Earth-Surface Processes  Management, Monitoring, Policy and Law  \
# 1970s                  1.190785                                1.068706
# 1980s                  1.082606                                1.075373
# 1990s                  0.905181                                1.038660
# 2000s                  1.021643                                0.967338
# 2010s                  0.970670                                1.015490
#
# decade  Mathematical Physics  Civil and Structural Engineering  \
# 1970s               0.997609                          1.111419
# 1980s               1.169344                          1.007613
# 1990s               0.864034                          1.178369
# 2000s               0.925359                          0.960262
# 2010s               1.209082                          0.845200
#
# decade  Geography, Planning and Development  Orthodontics  \
# 1970s                              0.980900      1.246478
# 1980s                              0.998258      1.056841
# 1990s                              1.028772      1.145891
# 2000s                              0.976846      0.983325
# 2010s                              1.115806      0.616623
#
# decade  Mathematics (miscellaneous)  Statistics, Probability and Uncertainty  \
# 1970s                      1.332416                                      NaN
# 1980s                      1.109438                                 1.209940
# 1990s                      0.689156                                 1.184680
# 2000s                      0.901170                                 1.213098
# 2010s                      1.014575                                 1.431896
#
# decade  Ocean Engineering  Industrial Relations  \
# 1970s            1.010692              0.851625
# 1980s            0.862041              1.000850
# 1990s            1.400531              0.905078
# 2000s            0.831403              1.057075
# 2010s            0.913340              1.145394
#
# decade  Safety, Risk, Reliability and Quality  Urban Studies  \
# 1970s                                0.867345       0.804139
# 1980s                                1.167994       0.987915
# 1990s                                0.985243       1.010491
# 2000s                                0.971710       0.971878
# 2010s                                0.963681       1.171903
#
# decade  Statistics and Probability  \
# 1970s                     0.919650
# 1980s                     0.968248
# 1990s                     1.030000
# 2000s                     0.911663
# 2010s                     1.068337
#
# decade  Earth and Planetary Sciences (miscellaneous)  Pediatrics  \
# 1970s                                       1.010713    1.027263
# 1980s                                       0.978516    0.739637
# 1990s                                       0.821816    1.059221
# 2000s                                       1.056617    1.022718
# 2010s                                       1.030110    1.035453
#
# decade  Paleontology  Geophysics  Neurology  Demography  Development  \
# 1970s       0.991011    1.061801   0.836202    0.895067     0.989317
# 1980s       0.968136    0.870790   1.256424    1.043132     0.908793
# 1990s       0.755888    0.929863   0.913913    0.865673     0.937827
# 2000s       1.110895    1.046375   0.820206    1.003972     0.921528
# 2010s       1.047080    0.962359   1.023075    1.005300     0.977743
#
# decade  General Engineering  Ecology, Evolution, Behavior and Systematics  \
# 1970s              1.014624                                      0.913513
# 1980s              1.024214                                      0.936558
# 1990s              1.013608                                      0.751486
# 2000s              0.843495                                      1.096114
# 2010s              0.838334                                      1.029518
#
# decade  Media Technology  Mechanical Engineering   Ecology  \
# 1970s           0.323692                1.012687  0.944051
# 1980s                NaN                0.981920  0.908301
# 1990s           1.319480                1.046412  0.886832
# 2000s           1.468433                0.918240  0.952249
# 2010s           1.609043                0.751020  0.999227
#
# decade  General Earth and Planetary Sciences  General Decision Sciences  \
# 1970s                               0.936054                        NaN
# 1980s                               0.880128                        NaN
# 1990s                               0.860925                   1.993857
# 2000s                               0.995297                   1.390381
# 2010s                               1.001185                   1.257086
#
# decade  Space and Planetary Science  Atmospheric Science  \
# 1970s                      1.094939             0.912000
# 1980s                      0.858047             0.868583
# 1990s                      0.642194             0.877150
# 2000s                      1.073247             1.021632
# 2010s                      0.966201             0.946329
#
# decade  Geriatrics and Gerontology   Geology  Health Policy  \
# 1970s                     0.824887  0.880862       0.960094
# 1980s                     0.854276  0.881296       0.907283
# 1990s                     1.059807  0.774628       0.952227
# 2000s                     0.873286  1.088026       0.796294
# 2010s                     0.965856  0.927532       0.934273
#
# decade  Global and Planetary Change  Automotive Engineering  \
# 1970s                      0.812492                     NaN
# 1980s                      1.102265                1.324684
# 1990s                      0.808247                1.180796
# 2000s                      0.873621                1.100035
# 2010s                      0.934370                0.921392
#
# decade  Fluid Flow and Transfer Processes  \
# 1970s                            0.993380
# 1980s                            0.800360
# 1990s                            1.041633
# 2000s                            0.976918
# 2010s                            0.624597
#
# decade  Cellular and Molecular Neuroscience  Oceanography  Optometry  \
# 1970s                              0.919204      0.929604   1.281160
# 1980s                              0.787526      0.759452   0.738162
# 1990s                              0.765230      0.977379   0.556771
# 2000s                              0.972479      0.773539   0.963618
# 2010s                              0.959762      0.951952   0.844788
#
# decade  General Physics and Astronomy  Physics and Astronomy (miscellaneous)  \
# 1970s                        0.914099                               0.927766
# 1980s                        0.944301                               0.963793
# 1990s                        0.811526                               0.698079
# 2000s                        0.871238                               0.923996
# 2010s                        0.819043                               0.835512
#
# decade  Conservation  Medicine (miscellaneous)  \
# 1970s       1.088827                  0.754173
# 1980s       0.820750                  0.893284
# 1990s       0.701370                  0.994615
# 2000s       0.644023                  0.906903
# 2010s       1.071014                  0.771933
#
# decade  Computer Science (miscellaneous)  Nuclear and High Energy Physics  \
# 1970s                                NaN                         0.936395
# 1980s                                NaN                         0.944289
# 1990s                           1.462647                         0.783725
# 2000s                           1.383789                         0.851354
# 2010s                           1.429522                         0.756274
#
# decade  Neurology (clinical)  General Health Professions  \
# 1970s               0.770762                    0.781116
# 1980s               0.819093                    0.920917
# 1990s               0.841192                    0.825028
# 2000s               0.954503                    0.750178
# 2010s               0.854330                    0.957377
#
# decade  Geotechnical Engineering and Engineering Geology  \
# 1970s                                           0.964780
# 1980s                                           0.772382
# 1990s                                           0.870606
# 2000s                                           0.867490
# 2010s                                           0.737482
#
# decade  Atomic and Molecular Physics, and Optics  \
# 1970s                                   1.010731
# 1980s                                   0.861541
# 1990s                                   0.774767
# 2000s                                   0.829935
# 2010s                                   0.713039
#
# decade  Endocrine and Autonomic Systems  General Environmental Science  \
# 1970s                               NaN                       0.934204
# 1980s                          1.082818                       0.879664
# 1990s                          0.731837                       0.871334
# 2000s                          1.125281                       0.739620
# 2010s                          1.207464                       0.719935
#
# decade  Electronic, Optical and Magnetic Materials  Forestry  \
# 1970s                                     0.825909  0.873354
# 1980s                                     1.109902  0.800900
# 1990s                                     0.698452  0.823234
# 2000s                                     0.797479  0.801868
# 2010s                                     0.706820  0.807976
#
# decade  Life-span and Life-course Studies  Chiropractics  Oral Surgery  \
# 1970s                                 NaN       0.819028      1.025045
# 1980s                                 NaN       0.619296      0.903871
# 1990s                            1.511579       0.787636      0.834231
# 2000s                            1.273322       0.999070      0.784536
# 2010s                            1.274884       0.817193      0.486929
#
# decade  Maternity and Midwifery  Critical Care Nursing  Insect Science  \
# 1970s                       NaN                    NaN        0.850190
# 1980s                  1.129488               1.088087        0.864913
# 1990s                  1.024192               1.153144        0.581654
# 2000s                  0.861950               0.790954        0.829678
# 2010s                  1.006889               0.976813        0.869433
#
# decade  Energy Engineering and Power Technology  Multidisciplinary  \
# 1970s                                  0.848540           0.915398
# 1980s                                  0.747560           0.863183
# 1990s                                  0.858066           0.805546
# 2000s                                  0.724393           0.657765
# 2010s                                  0.792195           0.722920
#
# decade  Mechanics of Materials  Advanced and Specialized Nursing  \
# 1970s                 0.826292                               NaN
# 1980s                 0.792953                          1.223590
# 1990s                 0.907514                          1.007132
# 2000s                 0.814165                          0.776156
# 2010s                 0.615049                          0.934861
#
# decade  Otorhinolaryngology  Animal Science and Zoology  Genetics (clinical)  \
# 1970s              0.865585                    0.887448             0.679944
# 1980s              0.798227                    0.826700             0.799375
# 1990s              0.660464                    0.658281             0.816453
# 2000s              0.783373                    0.852193             0.734340
# 2010s              0.828727                    0.708796             0.842422
#
# decade  Nuclear Energy and Engineering  Water Science and Technology  \
# 1970s                         0.689426                      0.842988
# 1980s                         0.698265                      0.665269
# 1990s                         0.985003                      0.841311
# 2000s                         0.760211                      0.682273
# 2010s                         0.721704                      0.808203
#
# decade  Anesthesiology and Pain Medicine  \
# 1970s                           0.650815
# 1980s                           0.785736
# 1990s                           0.766005
# 2000s                           0.811732
# 2010s                           0.821659
#
# decade  Public Health, Environmental and Occupational Health  \
# 1970s                                               0.678586
# 1980s                                               0.755432
# 1990s                                               0.775887
# 2000s                                               0.792616
# 2010s                                               0.824005
#
# decade  Physiology (medical)  Orthopedics and Sports Medicine  Horticulture  \
# 1970s               0.395677                         0.757254      1.064560
# 1980s               0.787729                         0.934197      0.796556
# 1990s               0.835933                         0.599779      0.592765
# 2000s               0.930625                         0.720939      0.662211
# 2010s               0.862219                         0.797337      0.659549
#
# decade  Numerical Analysis  Building and Construction  Metals and Alloys  \
# 1970s                  NaN                        NaN           0.757752
# 1980s             1.010213                   1.044113           0.830130
# 1990s             0.926032                   0.901365           0.809100
# 2000s             1.040789                   0.847098           0.851637
# 2010s             0.795060                   0.960248           0.503472
#
# decade  Geochemistry and Petrology  Oncology (nursing)  \
# 1970s                     0.706888                 NaN
# 1980s                     0.695607            1.002915
# 1990s                     0.486108            1.156969
# 2000s                     1.004541            0.661322
# 2010s                     0.840822            0.908002
#
# decade  Biomedical Engineering  \
# 1970s                 0.750725
# 1980s                 0.794163
# 1990s                 0.905228
# 2000s                 0.694116
# 2010s                 0.576973
#
# decade  Agricultural and Biological Sciences (miscellaneous)  \
# 1970s                                               0.832760
# 1980s                                               0.748671
# 1990s                                               0.758714
# 2000s                                               0.713748
# 2010s                                               0.665871
#
# decade  Nursing (miscellaneous)  Environmental Science (miscellaneous)  \
# 1970s                       NaN                                    NaN
# 1980s                  0.948433                               1.033883
# 1990s                  1.098616                               1.038422
# 2000s                  0.744317                               0.706577
# 2010s                  0.926542                               0.926916
#
# decade  Developmental Biology  Condensed Matter Physics  Physiology  \
# 1970s                0.917328                  0.780039    0.677157
# 1980s                0.826226                  0.873613    0.841505
# 1990s                0.684520                  0.665785    0.805629
# 2000s                0.680427                  0.720545    0.716833
# 2010s                0.581615                  0.604188    0.586697
#
# decade  General Agricultural and Biological Sciences  Gerontology  \
# 1970s                                       0.768926          NaN
# 1980s                                       0.728095     0.848566
# 1990s                                       0.684064     1.107143
# 2000s                                       0.734654     0.725283
# 2010s                                       0.676413     0.896057
#
# decade  Issues, Ethics and Legal Aspects  \
# 1970s                                NaN
# 1980s                                NaN
# 1990s                           1.226774
# 2000s                           1.078470
# 2010s                           1.257861
#
# decade  Renewable Energy, Sustainability and the Environment  Plant Science  \
# 1970s                                               0.691177       0.885106
# 1980s                                               0.765808       0.670500
# 1990s                                               0.845799       0.654517
# 2000s                                               0.509559       0.671942
# 2010s                                               0.745244       0.649265
#
# decade  Developmental Neuroscience  Critical Care and Intensive Care Medicine  \
# 1970s                          NaN                                   0.677684
# 1980s                     0.761982                                   0.678417
# 1990s                     0.771949                                   0.748940
# 2000s                     0.962875                                   0.670056
# 2010s                     1.019068                                   0.729004
#
# decade  Family Practice  Soil Science  Ophthalmology  General Energy  \
# 1970s               NaN      0.652645       0.886135        0.651095
# 1980s          1.213957      0.764607       0.824321        0.541378
# 1990s          0.843121      0.613607       0.389589        0.754154
# 2000s          0.650809      0.730920       0.712229        0.672169
# 2010s          0.774656      0.718687       0.667815        0.846896
#
# decade  Community and Home Care  Safety Research  Aquatic Science  \
# 1970s                       NaN              NaN         0.794834
# 1980s                       NaN              NaN         0.555009
# 1990s                  1.409428         1.114632         0.643001
# 2000s                  1.002833         1.295206         0.640797
# 2010s                  1.031591         1.032997         0.807946
#
# decade  General Medicine  Medical and Surgical Nursing  Research and Theory  \
# 1970s           0.706638                      0.702290                  NaN
# 1980s           0.760144                      0.396116                  NaN
# 1990s           0.716637                      0.594341             1.408128
# 2000s           0.599094                      0.899975             1.058138
# 2010s           0.653904                      0.836844             0.947913
#
# decade   Anatomy  Agronomy and Crop Science  Genetics  \
# 1970s   0.594585                   0.809516  0.746461
# 1980s   0.563089                   0.731063  0.800501
# 1990s   0.634353                   0.580301  0.520500
# 2000s   0.706063                   0.626409  0.634908
# 2010s   0.876363                   0.620353  0.651951
#
# decade  Radiology, Nuclear Medicine and Imaging  Ceramics and Composites  \
# 1970s                                  0.609494                 0.607812
# 1980s                                  0.653493                 0.703394
# 1990s                                  0.811132                 0.738578
# 2000s                                  0.586640                 0.751921
# 2010s                                  0.686659                 0.545310
#
# decade  General Dentistry  Catalysis  Instrumentation  \
# 1970s            0.727889   0.687787         0.762488
# 1980s            0.676966   0.732873         0.653271
# 1990s            0.766232   0.607113         0.794184
# 2000s            0.690323   0.669671         0.572075
# 2010s            0.450723   0.577641         0.483587
#
# decade  General Chemical Engineering  General Materials Science  \
# 1970s                       0.726774                   0.644740
# 1980s                       0.718450                   0.725294
# 1990s                       0.798017                   0.765228
# 2000s                       0.478044                   0.608400
# 2010s                       0.533198                   0.502054
#
# decade  Complementary and Alternative Medicine  \
# 1970s                                 0.710786
# 1980s                                 0.826789
# 1990s                                 0.643904
# 2000s                                 0.550412
# 2010s                                 0.507108
#
# decade  Pediatrics, Perinatology and Child Health   Surgery  Epidemiology  \
# 1970s                                    0.560363  0.715153      0.529017
# 1980s                                    0.682111  0.668637      0.713978
# 1990s                                    0.696220  0.604985      0.513432
# 2000s                                    0.480293  0.607789      0.669278
# 2010s                                    0.810068  0.614970      0.753870
#
# decade  Obstetrics and Gynecology  Environmental Engineering  \
# 1970s                    0.586984                   0.531977
# 1980s                    0.638156                   0.630058
# 1990s                    0.625424                   0.876598
# 2000s                    0.659871                   0.471165
# 2010s                    0.662585                   0.598336
#
# decade  Cardiology and Cardiovascular Medicine  Molecular Biology  \
# 1970s                                 0.684419           0.883820
# 1980s                                 0.752835           0.603399
# 1990s                                 0.690115           0.465573
# 2000s                                 0.443284           0.532675
# 2010s                                 0.501847           0.554726
#
# decade  Surfaces, Coatings and Films  Engineering (miscellaneous)  \
# 1970s                       0.548661                          NaN
# 1980s                       0.655937                          NaN
# 1990s                       0.681920                     1.307008
# 2000s                       0.605979                     1.040487
# 2010s                       0.533696                     0.673009
#
# decade  Reproductive Medicine  Fuel Technology  Materials Chemistry  \
# 1970s                0.552774         0.437060             0.652239
# 1980s                0.924613         0.623164             0.669986
# 1990s                0.440169         0.828679             0.573835
# 2000s                0.577746         0.511409             0.600861
# 2010s                0.516755         0.528529             0.430583
#
# decade  Periodontics  Biophysics  Cancer Research     Aging  Endocrinology  \
# 1970s       0.713528    0.636464         0.620739  0.762789       0.707801
# 1980s       0.894129    0.550453         0.778190  0.284968       0.680039
# 1990s       0.617830    0.517704         0.702899  0.658691       0.385019
# 2000s       0.366777    0.637605         0.389882  0.495209       0.519549
# 2010s       0.300048    0.537635         0.363060  0.637468       0.532814
#
# decade  Oncology  Radiological and Ultrasound Technology  Emergency Nursing  \
# 1970s   0.631627                                     NaN                NaN
# 1980s   0.634684                                0.841294           0.425084
# 1990s   0.736147                                     NaN           0.823515
# 2000s   0.330805                                1.102919           0.669950
# 2010s   0.478246                                0.857310           0.865075
#
# decade  Physical and Theoretical Chemistry  \
# 1970s                             0.655249
# 1980s                             0.652300
# 1990s                             0.511780
# 2000s                             0.483969
# 2010s                             0.443723
#
# decade  Endocrinology, Diabetes and Metabolism  \
# 1970s                                 0.735964
# 1980s                                 0.681046
# 1990s                                 0.487432
# 2000s                                 0.402687
# 2010s                                 0.438414
#
# decade  Pathology and Forensic Medicine  Fundamentals and Skills  \
# 1970s                          0.531370                      NaN
# 1980s                          0.574558                      NaN
# 1990s                          0.613917                 0.847971
# 2000s                          0.498274                 0.856410
# 2010s                          0.500984                 0.968908
#
# decade  Emergency Medicine  Cell Biology  Pulmonary and Respiratory Medicine  \
# 1970s                  NaN      0.646758                            0.450192
# 1980s             0.472091      0.621528                            0.872526
# 1990s             0.733398      0.474110                            0.526183
# 2000s             0.669435      0.441765                            0.266720
# 2010s             0.763774      0.420654                            0.476087
#
# decade  Rheumatology  Polymers and Plastics    Equine  \
# 1970s       0.611270               0.608753       NaN
# 1980s       0.633201               0.547919  0.896926
# 1990s       0.386866               0.686547  0.511121
# 2000s       0.430566               0.416049  0.744969
# 2010s       0.514382               0.302154  0.397170
#
# decade  General Biochemistry, Genetics and Molecular Biology  Virology  \
# 1970s                                               0.389451  0.538789
# 1980s                                               0.621015  0.486543
# 1990s                                               0.455534  0.597412
# 2000s                                               0.585442  0.379789
# 2010s                                               0.489395  0.526939
#
# decade  Transplantation  Internal Medicine   Urology  Nutrition and Dietetics  \
# 1970s          0.752585           0.581314  0.557415                 0.522462
# 1980s          0.423147           0.611074  0.671314                 0.425817
# 1990s          0.549582           0.490227  0.376956                 0.662808
# 2000s          0.186470           0.333385  0.470224                 0.338436
# 2010s          0.614348           0.502462  0.406483                 0.519192
#
# decade  Food Science  Inorganic Chemistry  Environmental Chemistry  \
# 1970s       0.791326             0.676710                 0.435921
# 1980s       0.281247             0.583260                 0.569881
# 1990s       0.721669             0.396109                 0.496780
# 2000s       0.156370             0.520351                 0.450224
# 2010s       0.493200             0.248565                 0.433562
#
# decade  Electrochemistry  Gastroenterology  Pharmacology (medical)  \
# 1970s                NaN          0.673307                0.599052
# 1980s           0.642244          0.550363                0.425372
# 1990s           0.822385          0.538004                0.480743
# 2000s           0.449510          0.136619                0.339538
# 2010s           0.467191          0.481347                0.487837
#
# decade  Hematology  General Veterinary  Waste Management and Disposal  \
# 1970s     0.641431            0.404018                            NaN
# 1980s     0.609023            0.571087                       0.608614
# 1990s     0.519020            0.439392                       0.556518
# 2000s     0.162029            0.561907                       0.583265
# 2010s     0.398069            0.342439                       0.559719
#
# decade  Immunology  Small Animals  Filtration and Separation  \
# 1970s     0.618584       0.280354                        NaN
# 1980s     0.558942       0.656680                   0.647441
# 1990s     0.357924       0.293052                   0.515616
# 2000s     0.271472       0.635730                   0.597645
# 2010s     0.486150       0.371379                   0.476300
#
# decade  General Chemistry  Pharmacology  Microbiology  Histology  \
# 1970s            0.531256      0.496737      0.547296   0.544615
# 1980s            0.489518      0.514508      0.379096   0.421815
# 1990s            0.469241      0.448778      0.513768   0.473728
# 2000s            0.398978      0.337880      0.362002   0.395198
# 2010s            0.306604      0.362225      0.347587   0.313701
#
# decade  Spectroscopy  Pollution  Microbiology (medical)  Hepatology  \
# 1970s       0.593168   0.359129                0.541983    0.480407
# 1980s       0.552622   0.307614                0.450111    0.348444
# 1990s       0.399697   0.522104                0.442465    0.702708
# 2000s       0.348308   0.505099                0.266152    0.156243
# 2010s       0.254528   0.439812                0.424836    0.428891
#
# decade  Biochemistry (medical)  Infectious Diseases  \
# 1970s                 0.406981             0.328914
# 1980s                 0.724600             0.472760
# 1990s                 0.552314             0.391651
# 2000s                 0.065139             0.322762
# 2010s                 0.355737             0.575664
#
# decade  Process Chemistry and Technology  Molecular Medicine  Parasitology  \
# 1970s                                NaN            0.432344      0.443913
# 1980s                           0.986512            0.373911      0.674662
# 1990s                           0.778583            0.302841      0.311146
# 2000s                                NaN            0.423647      0.293821
# 2010s                           0.301038            0.523177      0.308396
#
# decade  Applied Microbiology and Biotechnology  \
# 1970s                                 0.608360
# 1980s                                 0.344968
# 1990s                                 0.587480
# 2000s                                 0.123570
# 2010s                                 0.276838
#
# decade  Health, Toxicology and Mutagenesis  Biochemistry  Organic Chemistry  \
# 1970s                             0.296594      0.586243           0.567398
# 1980s                             0.535197      0.303558           0.254628
# 1990s                             0.358868      0.392984           0.432943
# 2000s                             0.377347      0.278734           0.353810
# 2010s                             0.347246      0.303067           0.245338
#
# decade  Biomaterials  Nephrology  Structural Biology  \
# 1970s       0.680053    0.332097                 NaN
# 1980s       0.311051    0.417744            0.405315
# 1990s       0.299191    0.511271            0.406999
# 2000s       0.247818    0.170654            0.461013
# 2010s       0.308742    0.351632            0.500916
#
# decade  Medical Laboratory Technology  Immunology and Allergy  \
# 1970s                             NaN                0.357351
# 1980s                        0.665749                0.724042
# 1990s                        0.324448                0.271561
# 2000s                             NaN                0.128090
# 2010s                        0.744458                0.249941
#
# decade  Pharmaceutical Science  Drug Discovery  Surfaces and Interfaces  \
# 1970s                 0.544574        0.344847                      NaN
# 1980s                 0.470640        0.585898                      NaN
# 1990s                 0.362345        0.331894                 0.437634
# 2000s                 0.126410        0.233227                 0.777872
# 2010s                 0.223697        0.227565                 0.479683
#
# decade  Computational Mechanics  Clinical Biochemistry  Dermatology  Pharmacy  \
# 1970s                       NaN               0.595443     0.472833       NaN
# 1980s                       NaN               0.404021     0.415922       NaN
# 1990s                       NaN               0.357679     0.189521       NaN
# 2000s                  0.951573               0.054768     0.290326  0.743549
# 2010s                  0.701494               0.236904     0.243552  0.849224
#
# decade  Economic Geology  Health Professions (miscellaneous)  Nurse Assisting  \
# 1970s                NaN                                 NaN              NaN
# 1980s                NaN                                 NaN              NaN
# 1990s                NaN                                 NaN              NaN
# 2000s           0.861071                            0.891083         1.043551
# 2010s           0.706065                            0.670081         0.510978
#
# decade  Toxicology  Bioengineering  Biotechnology  \
# 1970s     0.297131        0.888339            NaN
# 1980s     0.355031        0.227838       0.463978
# 1990s     0.338448             NaN       0.626516
# 2000s     0.353166        0.098560       0.100675
# 2010s     0.206414        0.313455       0.330011
#
# decade  Colloid and Surface Chemistry  Radiation  Analytical Chemistry  \
# 1970s                             NaN   0.338109              0.414020
# 1980s                        0.311111   0.248488              0.323156
# 1990s                        0.468111   0.189816              0.410471
# 2000s                        0.350930   0.255221              0.125449
# 2010s                        0.360871   0.345926              0.096081
#
# decade  Chemical Engineering (miscellaneous)  Dentistry (miscellaneous)  \
# 1970s                                    NaN                        NaN
# 1980s                                    NaN                        NaN
# 1990s                               0.648984                        NaN
# 2000s                                    NaN                   0.645194
# 2010s                               0.565847                   0.502393
#
# decade  Pharmacology (nursing)  \
# 1970s                      NaN
# 1980s                      NaN
# 1990s                      NaN
# 2000s                 0.438510
# 2010s                 0.659929
#
# decade  Pharmacology, Toxicology and Pharmaceutics (miscellaneous)  \
# 1970s                                                          NaN
# 1980s                                                          NaN
# 1990s                                                          NaN
# 2000s                                                     0.242515
# 2010s                                                     0.853782
#
# decade  Materials Science (miscellaneous)  Energy (miscellaneous)  \
# 1970s                                 NaN                     NaN
# 1980s                                 NaN                     NaN
# 1990s                                 NaN                     NaN
# 2000s                            0.446015                     NaN
# 2010s                            0.581620                0.946511
#
# decade  Food Animals  Complementary and Manual Therapy  \
# 1970s            NaN                               NaN
# 1980s            NaN                               NaN
# 1990s            NaN                               NaN
# 2000s       0.608888                               NaN
# 2010s       0.299064                          0.851355
#
# decade  Veterinary (miscellaneous)  Chemistry (miscellaneous)  \
# 1970s                          NaN                        NaN
# 1980s                          NaN                        NaN
# 1990s                          NaN                        NaN
# 2000s                     0.728601                    0.76829
# 2010s                     0.042308                        NaN
#
# decade  General Pharmacology, Toxicology and Pharmaceutics  \
# 1970s                                                  NaN
# 1980s                                                  NaN
# 1990s                                             0.387232
# 2000s                                             0.024604
# 2010s                                             0.260757
#
# decade  General Immunology and Microbiology  \
# 1970s                                   NaN
# 1980s                                   NaN
# 1990s                                   NaN
# 2000s                              0.276287
# 2010s                              0.210397
#
# decade  Immunology and Microbiology (miscellaneous)  Dental Assisting  \
# 1970s                                           NaN               NaN
# 1980s                                      0.403415               NaN
# 1990s                                           NaN               NaN
# 2000s                                           NaN               NaN
# 2010s                                           NaN           0.37895
#
# decade  Assessment and Diagnosis  \
# 1970s                        NaN
# 1980s                        NaN
# 1990s                        NaN
# 2000s                   0.366798
# 2010s                        NaN
#
# decade  Biochemistry, Genetics and Molecular Biology (miscellaneous)
# 1970s                                                            NaN
# 1980s                                                            NaN
# 1990s                                                            NaN
# 2000s                                                            NaN
# 2010s                                                       0.238844

# %%
color_dict = {'Experimental and Cognitive Psychology': '#a6cee3',	
              'Linguistics and Language': '#1f78b4',	
              'Developmental and Educational Psychology': '#b2df8a',	
              'Artificial Intelligence': '#33a02c',	
              'Cognitive Neuroscience': '#fb9a99',
              'Education': '#e31a1c',	
              'Philosophy': '#fdbf6f',
              'others': '#b3b3b3'}

fig = plt.figure(figsize=(10,12), dpi=300)

plt.subplot(2,1,1)
ax = count_df.plot(kind ='bar', stacked = True, ax=plt.gca(),
                   xlabel='decade', ylabel='percentage of papers published (%)', rot=0,
                   color=color_dict)
box = ax.get_position()
ax.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
          edgecolor='white', ncol=3)

plt.subplot(2,1,2)
ax_cs = cs_df[['Experimental and Cognitive Psychology',
               'Philosophy', 
               'Artificial Intelligence']].plot(kind ='bar', ax=plt.gca(), 
                                                xlabel='decade', ylabel='Mean(subarea)/Mean(general)', rot=0,
                                                color=color_dict)
ax_cs.set_ylim(1.4, 2.7)
box = ax_cs.get_position()
ax_cs.set_position([box.x0, box.y0 + box.height * 0.1,
                 box.width, box.height * 0.9])
ax_cs.legend(loc='upper center', bbox_to_anchor=(0.5, -0.1),
             edgecolor='white', ncol=3)

plt.show()

# %%
fig.savefig('Cognitive Science.pdf', 
            dpi = 300, 
            facecolor='white', 
            transparent=False, 
            bbox_inches='tight')
