# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys 
sys.path.append("..") 

# %aimport p2v

# %%
from multiprocessing.pool import Pool
import tqdm
import pickle

# %%
model = p2v.P2V()
# Out:
# 2023-09-01 22:49:35 -- start loading Mag_venue_info_df
# 2023-09-01 22:49:35 -- finish.
# 2023-09-01 22:49:35 -- start loading labeled_journal_info_df
# 2023-09-01 22:49:35 -- finish.

# %%
def filter_walk(walk: list):
    if len(set(walk)) == 1:
        pass
    else:
        return walk

# %%
start_year_list = ['1950', '1960', '1970', '1980', '1990', '2000', '2010']
end_year_list = ['1959', '1969', '1979', '1989', '1999', '2009', '2021']

for i in range(0, 7):
    model.load_walks(start_year_list[i], end_year_list[i])
    with Pool() as pool:
      filtered_walks = list(tqdm.tqdm(pool.imap(filter_walk, model.walks), total=100))
    with open('/media/sdb/p2v/pickles/decades/%s_to_%s/filtered_walks.pkl' %(start_year_list[i], end_year_list[i]), 'wb') as list_file:
        pickle.dump(filtered_walks, list_file)
    prinT("The file \'filtered_walks.pkl\' is ready, %d walks generated" %len(self.walks))
    prinT("{}/{} years generated...".format(i+1, len(start_year_list)))
# Out:
# 2023-09-01 22:56:55 -- start loading walks...
# 2023-09-01 22:56:59 -- finish.
# 277009it [00:27, 10246.54it/s]         Process ForkPoolWorker-167:
# Process ForkPoolWorker-177:
#
# Process ForkPoolWorker-181:
# Process ForkPoolWorker-146:
# Process ForkPoolWorker-190:
# Process ForkPoolWorker-173:
# Process ForkPoolWorker-165:
# Process ForkPoolWorker-168:
# Process ForkPoolWorker-135:
# Process ForkPoolWorker-133:
# Process ForkPoolWorker-161:
# Process ForkPoolWorker-186:
# Process ForkPoolWorker-166:
# Process ForkPoolWorker-178:
# Process ForkPoolWorker-155:
# Process ForkPoolWorker-136:
# Process ForkPoolWorker-137:
# Process ForkPoolWorker-163:
# Process ForkPoolWorker-180:
# Process ForkPoolWorker-174:
# Process ForkPoolWorker-189:
# Process ForkPoolWorker-172:
# Process ForkPoolWorker-175:
# Process ForkPoolWorker-148:
# Process ForkPoolWorker-192:
# Process ForkPoolWorker-134:
# Process ForkPoolWorker-158:
# Process ForkPoolWorker-187:
# Process ForkPoolWorker-185:
# ...
