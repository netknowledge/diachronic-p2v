# %%
pip install pandarallel
# Out:
# Collecting pandarallel
#   Downloading pandarallel-1.6.5.tar.gz (14 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: dill>=0.3.1 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandarallel) (0.3.6)
# Requirement already satisfied: pandas>=1 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandarallel) (1.5.3)
# Requirement already satisfied: psutil in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandarallel) (5.9.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandas>=1->pandarallel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandas>=1->pandarallel) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from pandas>=1->pandarallel) (1.24.3)
# Requirement already satisfied: six>=1.5 in /Users/pigeont/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.1->pandas>=1->pandarallel) (1.16.0)
# Building wheels for collected packages: pandarallel
#   Building wheel for pandarallel (setup.py) ... done
#   Created wheel for pandarallel: filename=pandarallel-1.6.5-py3-none-any.whl size=16676 sha256=d6e153c77f07ff6009be609e4a73c0a2d3e0c75a46b9db00d6f90802a571dedc
#   Stored in directory: /Users/pigeont/Library/Caches/pip/wheels/b9/c6/5a/829298789e94348b81af52ab42c19d49da007306bbcc983827
# Successfully built pandarallel
# Installing collected packages: pandarallel
# Successfully installed pandarallel-1.6.5
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set_style('ticks')

from scipy.linalg import orthogonal_procrustes
from sklearn.metrics.pairwise import cosine_similarity, paired_distances

import sys
sys.path.append("..") 

import p2v

# %%
model = p2v.P2V()
# Out:
# 2023-12-17 13:02:22 -- start loading Mag_venue_info_df
# 2023-12-17 13:02:23 -- finish.
# 2023-12-17 13:02:23 -- start loading labeled_journal_info_df
# 2023-12-17 13:02:23 -- finish.

# %%
periods = [('1950', '1959'), ('1960', '1969'), ('1970', '1979'), ('1980', '1989'), ('1990', '1999'), ('2000', '2009'), ('2010', '2021')]
wv_models = [model.load_wv(b, e, 100, 10) for b, e in periods]
len(wv_models)
# Out:
# 2023-12-17 13:02:26 -- start loading word vectors...
# 2023-12-17 13:02:26 -- word vectors loaded, and its shape is: (1645, 100)
# 2023-12-17 13:02:26 -- start loading word vectors...
# 2023-12-17 13:02:26 -- word vectors loaded, and its shape is: (3116, 100)
# 2023-12-17 13:02:26 -- start loading word vectors...
# 2023-12-17 13:02:27 -- word vectors loaded, and its shape is: (5686, 100)
# 2023-12-17 13:02:27 -- start loading word vectors...
# 2023-12-17 13:02:27 -- word vectors loaded, and its shape is: (9337, 100)
# 2023-12-17 13:02:27 -- start loading word vectors...
# 2023-12-17 13:02:27 -- word vectors loaded, and its shape is: (15019, 100)
# 2023-12-17 13:02:27 -- start loading word vectors...
# 2023-12-17 13:02:27 -- word vectors loaded, and its shape is: (27460, 100)
# 2023-12-17 13:02:27 -- start loading word vectors...
# 2023-12-17 13:02:27 -- word vectors loaded, and its shape is: (37594, 100)
# 7

# %%
with open('/media/sdb/p2v/pickles/decades/1950_to_1959/100feat_10context_win_size','rb') as f:
    print(f)
# Out:
# <_io.BufferedReader name='/media/sdb/p2v/pickles/decades/1950_to_1959/100feat_10context_win_size'>

# %%
vids = set()
for m in wv_models:
    vids.update(m.index_to_key)
    print(m)
len(vids)
# Out:
# KeyedVectors<vector_size=100, 1645 keys>
# KeyedVectors<vector_size=100, 3116 keys>
# KeyedVectors<vector_size=100, 5686 keys>
# KeyedVectors<vector_size=100, 9337 keys>
# KeyedVectors<vector_size=100, 15019 keys>
# KeyedVectors<vector_size=100, 27460 keys>
# KeyedVectors<vector_size=100, 37594 keys>
# 43603

# %%
0 in vids
# Out:
# True

# %%
def get_venue_semantic_change():
    """"""
    alignment = []
    result = []
    for i in range(0, len(wv_models)-1):
        source_model = wv_models[i]
        target_model = wv_models[i+1]

        source_vids = source_model.index_to_key
        target_vids = target_model.index_to_key
        shared_vids = list(set(source_vids) & set(target_vids))
        print(len(shared_vids))

        source_idx = [source_model.get_index(v) for v in shared_vids]
        target_idx = [target_model.get_index(v) for v in shared_vids]

        source_vectors = source_model.get_normed_vectors()[source_idx]
        target_vectors = target_model.get_normed_vectors()[target_idx]

        R, sca = orthogonal_procrustes(source_vectors, target_vectors)
        aligned_source_vectors = np.dot(source_vectors, R)
        alignment.append((aligned_source_vectors, R))

        dist = paired_distances(aligned_source_vectors, target_vectors, metric='cosine')
        change = dict(zip([str(int(v)) for v in shared_vids], dist))
        result.append(change)
    vid_name = {str(k): v for k, v in model.MAG_venue_info_df.OriginalVenue.to_dict().items()}
    vids = set().union(*[list(d.keys()) for d in result])
    rows = []
    for v in vids:
        row = [v, vid_name[v]]
        row.extend(d.get(v, np.nan) for d in result)
        rows.append(row)
    df = pd.DataFrame(rows, columns=['vid', 'name']+['cos_dist_'+periods[i][0]+'s' for i in range(0, len(wv_models)-1)])
    return df, alignment

vid_dist_df, alignment = get_venue_semantic_change()
vid_dist_df.shape
# Out:
# 1500
# 2809
# 5144
# 8436
# 13405
# 24250
# (27048, 8)

# %%
start_year = 1950
end_year = 1959
d = 100 
w = 10 


VID_labeled = model.load_VID_labeled(start_year, end_year, d, w)


if not isinstance(VID_labeled, pd.DataFrame):
    VID_labeled = pd.DataFrame(VID_labeled)

VID_labeled['VID'] = VID_labeled['VID'].astype(str)
vid_dist_df['vid'] = vid_dist_df['vid'].astype(str)

vid_dist_df = vid_dist_df.merge(VID_labeled, left_on='vid', right_on='VID', how='left')

vid_dist_df.drop(columns=['VID'], inplace=True)

vid_dist_df
# Out:
# 2023-12-17 13:02:55 -- start loading VID_labeled...
# 2023-12-17 13:02:55 -- finish.
#               vid                                               name  \
# 0      2765035712                    Asian Journal of Geoinformatics
# 1      1150832739                bangalore annual compute conference
# 2      2764851652  Schole: A Journal of Leisure Studies and Recre...
# 3      2754977200                                      Health estate
# 4       158124418                   Frontiers of Philosophy in China
# ...           ...                                                ...
# 27043  2623329905   international interconnect technology conference
# 27044    96072387                              Men and Masculinities
# 27045    77500791          Asia-pacific Journal of Clinical Oncology
# 27046   194017625                Revista Internacional De Acupuntura
# 27047  2621892505                 pulp and paper industry conference
#
#        cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  cos_dist_1980s  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 27043             NaN             NaN             NaN             NaN
# 27044             NaN             NaN             NaN             NaN
# 27045             NaN             NaN             NaN             NaN
# 27046             NaN             NaN             NaN             NaN
# 27047             NaN             NaN             NaN        0.300136
#
#        cos_dist_1990s  cos_dist_2000s label subarea_label year_founded
# 0                 NaN        0.251585   NaN           NaN          NaN
# 1                 NaN        0.343911   NaN           NaN          NaN
# 2            0.243588        0.310168   NaN           NaN          NaN
# 3                 NaN        0.262512   NaN           NaN          NaN
# 4                 NaN        0.246874   NaN           NaN          NaN
# ...               ...             ...   ...           ...          ...
# 27043        0.251516        0.280210   NaN           NaN          NaN
# 27044        0.287034        0.268415   NaN           NaN          NaN
# 27045             NaN        0.206201   NaN           NaN          NaN
# 27046             NaN        0.425683   NaN           NaN          NaN
# 27047        0.368064        0.330564   NaN           NaN          NaN
#
# [27048 rows x 11 columns]

# %%
vid_dist_df[vid_dist_df.name == 'Nature']
# Out:
#             vid    name  cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  \
# 4900  137773608  Nature        0.141203         0.18624        0.156809
#
#       cos_dist_1980s  cos_dist_1990s  cos_dist_2000s              label  \
# 4900        0.165275        0.179417        0.191892  Multidisciplinary
#
#           subarea_label year_founded  max_dist  total_dist  cos_dist_sum
# 4900  Multidisciplinary         1869  0.191892    1.020836      1.020836

# %%
def get_first_decade(row):
    """"""
    if row[2]

# %%
vid_dist_df.drop(columns=['total', 'max_dist'], inplace=True)

# %%
vid_dist_df['max_dist'] = vid_dist_df[['cos_dist_1950s', 'cos_dist_1960s', 'cos_dist_1970s', 'cos_dist_1980s', 'cos_dist_1990s', 'cos_dist_2000s']].max(axis=1)

# %%
vid_dist_df['total_dist'] = vid_dist_df[['cos_dist_1950s', 'cos_dist_1960s', 'cos_dist_1970s', 'cos_dist_1980s', 'cos_dist_1990s', 'cos_dist_2000s']].sum(axis=1)

# %%
def plot_distance_distribution_update(save=False):
    fig, axes = plt.subplots(2, 3, sharex=True, sharey=False, figsize=(10,6))
    for c, ax in zip(decade_cols, axes.flatten()):
        start_year = c.replace('cos_dist_', '')[:4]
        end_year = str(int(start_year) + 10) 
        title = f"{start_year} -> {end_year}"
        vid_dist_df[c].plot.hist(ax=ax, bins=30, color='0.5', grid=False)
        ax.set_title(title)
    axes[1,1].set(xlabel='Cosine distance')
    for j in [1,2]:
        axes[0,j].set(ylabel='')
        axes[1,j].set(ylabel='')
    if save:
        plt.savefig('./figs/jnl_aligned_dist_hist.pdf', bbox_inches='tight')

    plt.tight_layout()

plot_distance_distribution_update(True)

# %%
vid_dist_df
# Out:
#               vid                                               name  \
# 0      2765035712                    Asian Journal of Geoinformatics
# 1      1150832739                bangalore annual compute conference
# 2      2764851652  Schole: A Journal of Leisure Studies and Recre...
# 3      2754977200                                      Health estate
# 4       158124418                   Frontiers of Philosophy in China
# ...           ...                                                ...
# 27043  2623329905   international interconnect technology conference
# 27044    96072387                              Men and Masculinities
# 27045    77500791          Asia-pacific Journal of Clinical Oncology
# 27046   194017625                Revista Internacional De Acupuntura
# 27047  2621892505                 pulp and paper industry conference
#
#        cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  cos_dist_1980s  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 27043             NaN             NaN             NaN             NaN
# 27044             NaN             NaN             NaN             NaN
# 27045             NaN             NaN             NaN             NaN
# 27046             NaN             NaN             NaN             NaN
# 27047             NaN             NaN             NaN        0.300136
#
#        cos_dist_1990s  cos_dist_2000s label subarea_label year_founded  \
# 0                 NaN        0.251585   NaN           NaN          NaN
# 1                 NaN        0.343911   NaN           NaN          NaN
# 2            0.243588        0.310168   NaN           NaN          NaN
# 3                 NaN        0.262512   NaN           NaN          NaN
# 4                 NaN        0.246874   NaN           NaN          NaN
# ...               ...             ...   ...           ...          ...
# 27043        0.251516        0.280210   NaN           NaN          NaN
# 27044        0.287034        0.268415   NaN           NaN          NaN
# 27045             NaN        0.206201   NaN           NaN          NaN
# 27046             NaN        0.425683   NaN           NaN          NaN
# 27047        0.368064        0.330564   NaN           NaN          NaN
#
#        max_dist  total_dist
# 0      0.251585    0.251585
# 1      0.343911    0.343911
# 2      0.310168    0.553756
# 3      0.262512    0.262512
# 4      0.246874    0.246874
# ...         ...         ...
# 27043  0.280210    0.531726
# 27044  0.287034    0.555450
# 27045  0.206201    0.206201
# 27046  0.425683    0.425683
# 27047  0.368064    0.998764
#
# [27048 rows x 13 columns]

# %%
def plot_cumulative_distance_distribution(save=False):
    cumulative_distributions = {}
    for i, col in enumerate(decade_cols):
        cumulative_distributions[col] = vid_dist_df[decade_cols[i:]].values.flatten()

    fig, axes = plt.subplots(2, 3, sharex=True, sharey=True, figsize=(10, 6))
    for ax, (decade, data) in zip(axes.flatten(), cumulative_distributions.items()):
        ax.hist(data[~np.isnan(data)], bins=30, color='0.5')
        start_year = decade.replace('cos_dist_', '')[:4]
        title = f"{start_year} -> 2010"
        ax.set_title(title)
        ax.grid(False)

    fig.text(0.5, 0.01, 'Cosine distance', ha='center', va='center')
    fig.text(0.01, 0.5, 'Frequency', ha='center', va='center', rotation='vertical')
    
    plt.tight_layout()

    if save:
        plt.savefig('./figs/jnl_aligned_dist_hist_cumulative.pdf', bbox_inches='tight')


plot_cumulative_distance_distribution(True)

# %%
vid_dist_df['cos_dist_sum'] = vid_dist_df[decade_cols].sum(axis=1)

vid_dist_df
# Out:
#               vid                                               name  \
# 0      2765035712                    Asian Journal of Geoinformatics
# 1      1150832739                bangalore annual compute conference
# 2      2764851652  Schole: A Journal of Leisure Studies and Recre...
# 3      2754977200                                      Health estate
# 4       158124418                   Frontiers of Philosophy in China
# ...           ...                                                ...
# 27043  2623329905   international interconnect technology conference
# 27044    96072387                              Men and Masculinities
# 27045    77500791          Asia-pacific Journal of Clinical Oncology
# 27046   194017625                Revista Internacional De Acupuntura
# 27047  2621892505                 pulp and paper industry conference
#
#        cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  cos_dist_1980s  \
# 0                 NaN             NaN             NaN             NaN
# 1                 NaN             NaN             NaN             NaN
# 2                 NaN             NaN             NaN             NaN
# 3                 NaN             NaN             NaN             NaN
# 4                 NaN             NaN             NaN             NaN
# ...               ...             ...             ...             ...
# 27043             NaN             NaN             NaN             NaN
# 27044             NaN             NaN             NaN             NaN
# 27045             NaN             NaN             NaN             NaN
# 27046             NaN             NaN             NaN             NaN
# 27047             NaN             NaN             NaN        0.300136
#
#        cos_dist_1990s  cos_dist_2000s label subarea_label year_founded  \
# 0                 NaN        0.251585   NaN           NaN          NaN
# 1                 NaN        0.343911   NaN           NaN          NaN
# 2            0.243588        0.310168   NaN           NaN          NaN
# 3                 NaN        0.262512   NaN           NaN          NaN
# 4                 NaN        0.246874   NaN           NaN          NaN
# ...               ...             ...   ...           ...          ...
# 27043        0.251516        0.280210   NaN           NaN          NaN
# 27044        0.287034        0.268415   NaN           NaN          NaN
# 27045             NaN        0.206201   NaN           NaN          NaN
# 27046             NaN        0.425683   NaN           NaN          NaN
# 27047        0.368064        0.330564   NaN           NaN          NaN
#
#        max_dist  total_dist  cos_dist_sum
# 0      0.251585    0.251585      0.251585
# 1      0.343911    0.343911      0.343911
# 2      0.310168    0.553756      0.553756
# 3      0.262512    0.262512      0.262512
# 4      0.246874    0.246874      0.246874
# ...         ...         ...           ...
# 27043  0.280210    0.531726      0.531726
# 27044  0.287034    0.555450      0.555450
# 27045  0.206201    0.206201      0.206201
# 27046  0.425683    0.425683      0.425683
# 27047  0.368064    0.998764      0.998764
#
# [27048 rows x 14 columns]

# %%
def plot_subject_distance_distribution(save=False):
    sns.set(style="whitegrid")

    median_order = vid_dist_df.groupby('label')['cos_dist_sum'].median().sort_values(ascending=False).index
    
    plt.figure(figsize=(10, 8)) 
    ax = sns.boxplot(x='label', y='cos_dist_sum', data=vid_dist_df, order=median_order)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45, horizontalalignment='right') 
    ax.set_xlabel('')
    ax.set_ylabel('Total semantic change')
    ax.grid(False)


    plt.tight_layout() 
    if save:
        plt.savefig('./figs/jnl_subject_dist_boxplot.pdf', bbox_inches='tight')


plot_subject_distance_distribution(True)

# %%
vid_dist_df.sort_values('total_dist', ascending=False)[:10]
# Out:
#               vid                                               name  \
# 17655   203291325                                 American Scientist
# 21513   196862746  Biographical Memoirs of Fellows of the Royal S...
# 10601    65315170                                          Endeavour
# 9230    169320561                                Scientia Forestalis
# 7037     61392201               Yale Journal of Biology and Medicine
# 21688  2764711651  Philosophical transactions - Royal Society. Ma...
# 17575     9683234                                   Science Progress
# 9475   2764845328                    Methods of biochemical analysis
# 16097  2764830181         Journal of the Arkansas Academy of Science
# 6360      4310451                                         Homeopathy
#
#        cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  cos_dist_1980s  \
# 17655        0.601703        0.583388        0.564318        0.613295
# 21513        0.403270        0.497840        0.633888        0.658773
# 10601        0.571602        0.633583        0.534574        0.478185
# 9230         0.552816        0.389587        0.523438        0.552727
# 7037         0.488857        0.497459        0.583340        0.563390
# 21688        0.431722        0.439238        0.472242        0.528418
# 17575             NaN        0.658248        0.583763        0.543106
# 9475         0.290292        0.445806        0.485273        0.449243
# 16097        0.291943        0.405497        0.400058        0.720701
# 6360         0.611821        0.483312        0.493173        0.663064
#
#        cos_dist_1990s  cos_dist_2000s  max_dist  total_dist  z_cos_dist_1950s  \
# 17655        0.628166        0.565060  0.628166    3.555930          4.183176
# 21513        0.537014        0.708058  0.708058    3.438844          1.815264
# 10601        0.585333        0.423860  0.633583    3.227137          3.823980
# 9230         0.614540        0.593261  0.614540    3.226369          3.599800
# 7037         0.577794        0.510129  0.583340    3.220969          2.836578
# 21688        0.597885        0.689716  0.689716    3.159221          2.154773
# 17575        0.560335        0.743449  0.743449    3.088901               NaN
# 9475         0.634068        0.734298  0.734298    3.038980          0.467082
# 16097        0.560790        0.642926  0.720701    3.021917          0.486787
# 6360         0.389822        0.351778  0.663064    2.992970          4.303912
#
#        z_cos_dist_1960s  z_cos_dist_1970s  z_cos_dist_1980s  z_cos_dist_1990s  \
# 17655          3.549811          3.258641          3.816813          3.891069
# 21513          2.574641          4.046862          4.338125          2.841799
# 10601          4.121981          2.921639          2.268090          3.398006
# 9230           1.340658          2.795465          3.122548          3.734220
# 7037           2.570297          3.474149          3.244772          3.311228
# 21688          1.906627          2.215424          2.843898          3.542501
# 17575          4.403146          3.478952          3.012256          3.110253
# 9475           1.981502          2.363060          1.936332          3.959010
# 16097          1.522018          1.397591          5.047989          3.115494
# 6360           2.409038          2.452574          4.387301          1.147459
#
#        z_cos_dist_2000s
# 17655          3.013447
# 21513          4.565569
# 10601          1.480843
# 9230           3.319543
# 7037           2.417219
# 21688          4.366490
# 17575          4.949715
# 9475           4.850384
# 16097          3.858623
# 6360           0.698452

# %%
vid_dist_df[vid_dist_df.vid == '67393510']
# Out:
#             vid               name  cos_dist_1950s  cos_dist_1960s  \
# 19543  67393510  Angewandte Chemie        0.237511         0.24444
#
#        cos_dist_1970s  cos_dist_1980s  cos_dist_1990s  cos_dist_2000s  \
# 19543        0.303967        0.209501        0.173861          0.0987
#
#        max_dist  total_dist  z_cos_dist_1950s  z_cos_dist_1960s  \
# 19543  0.303967    1.267981         -0.162751         -0.313886
#
#        z_cos_dist_1970s  z_cos_dist_1980s  z_cos_dist_1990s  z_cos_dist_2000s
# 19543          0.308886         -0.811763         -1.338496           -2.0485

# %%
vid_dist_df[vid_dist_df.cos_dist_1950s.isna() & vid_dist_df.cos_dist_1960s.isna() & vid_dist_df.cos_dist_1970s.isna()].sort_values('total_dist', ascending=False)[30:40]
# Out:
#               vid                                               name  \
# 25894   202685627                                  Panminerva Medica
# 17677   173121395  Journal of Automated Methods & Management in C...
# 10671    55067821                            Gaceta Medica De Mexico
# 17184   174634489           Historical Records of Australian Science
# 10463    71577765                       Advances in Chemical Physics
# 2085   2764558583                Journal of Life Support Engineering
# 22079   203621788             Journal of The Vacuum Society of Japan
# 13589  2754723957           The Kobe journal of the medical sciences
# 23771   162280541                               The Environmentalist
# 20674    52256385                                          Biosilico
#
#        cos_dist_1950s  cos_dist_1960s  cos_dist_1970s  cos_dist_1980s  \
# 25894             NaN             NaN             NaN        0.420370
# 17677             NaN             NaN             NaN        0.529642
# 10671             NaN             NaN             NaN        0.439442
# 17184             NaN             NaN             NaN        0.454563
# 10463             NaN             NaN             NaN        0.386755
# 2085              NaN             NaN             NaN        0.590421
# 22079             NaN             NaN             NaN        0.547878
# 13589             NaN             NaN             NaN        0.417406
# 23771             NaN             NaN             NaN        0.412358
# 20674             NaN             NaN             NaN             NaN
#
#        cos_dist_1990s  cos_dist_2000s  max_dist  total_dist  z_cos_dist_1950s  \
# 25894        0.462861        0.516237  0.516237    1.399468               NaN
# 17677        0.438235        0.427142  0.529642    1.395019               NaN
# 10671        0.526959        0.423714  0.526959    1.390114               NaN
# 17184        0.481427        0.443156  0.481427    1.379146               NaN
# 10463        0.480538        0.506571  0.506571    1.373864               NaN
# 2085         0.333378        0.440469  0.590421    1.364268               NaN
# 22079        0.398103        0.414061  0.547878    1.360041               NaN
# 13589        0.563597        0.378722  0.563597    1.359725               NaN
# 23771        0.558935        0.384873  0.558935    1.356165               NaN
# 20674        0.385198        0.966993  0.966993    1.352191               NaN
#
#        z_cos_dist_1960s  z_cos_dist_1970s  z_cos_dist_1980s  z_cos_dist_1990s  \
# 25894               NaN               NaN          1.605374          1.988222
# 17677               NaN               NaN          2.857927          1.704748
# 10671               NaN               NaN          1.823990          2.726057
# 17184               NaN               NaN          1.997313          2.201935
# 10463               NaN               NaN          1.220049          2.191701
# 2085                NaN               NaN          3.554615          0.497718
# 22079               NaN               NaN          3.066956          1.242776
# 13589               NaN               NaN          1.571399          3.147803
# 23771               NaN               NaN          1.513529          3.094135
# 20674               NaN               NaN               NaN          1.094231
#
#        z_cos_dist_2000s
# 25894          2.483515
# 17677          1.516461
# 10671          1.479253
# 17184          1.690283
# 10463          2.378599
# 2085           1.661123
# 22079          1.374483
# 13589          0.990902
# 23771          1.057671
# 20674          7.376094

# %%
vid_dist_df[vid_dist_df.name == 'Advanced Materials']
# Out:
#            vid                name  cos_dist_1950s  cos_dist_1960s  \
# 7233  99352657  Advanced Materials             NaN             NaN
#
#       cos_dist_1970s  cos_dist_1980s  cos_dist_1990s  cos_dist_2000s  \
# 7233             NaN        0.337035        0.142957        0.174166
#
#       max_dist  total_dist  z_cos_dist_1950s  z_cos_dist_1960s  \
# 7233  0.337035    0.654158               NaN               NaN
#
#       z_cos_dist_1970s  z_cos_dist_1980s  z_cos_dist_1990s  z_cos_dist_2000s
# 7233               NaN          0.650123         -1.694244         -1.229374

# %%
def plot_venue_semantic_change(save=False):
    """"""
    venues = [('Philosophical Transactions of the Royal Society A', 'Philos Trans R Soc A'), 
              ('Annals of the New York Academy of Sciences', 'Ann N Y Acad Sci'), 
              ('Proceedings of The Royal Society B: Biological Sciences', 'Proc R Soc B'), 
              ('Journal of The Royal Statistical Society Series C-applied Statistics', 'J R Stat Soc C'), 
              ('The American review of respiratory disease', ''), 
              ('Econometrica', 'Econometrica'), 
              ('Science', 'Science'), 
              ('Nature', 'Nature'), 
              ('Proceedings of the National Academy of Sciences of the United States of America', 'PNAS'),
              ('The Lancet', 'Lancet'), 
              ('The New England Journal of Medicine', 'NEJM'), 
              ('JAMA', 'JAMA'), 
              ('BMJ', 'BMJ'), 
              ('British Journal of Radiology', 'Br. J. Radiol.'), 
              ('American Journal of Public Health', ''), 
              ('Angewandte Chemie', 'Angewandte Chemie'), 
              ('Bioinformatics', 'Bioinformatics'), 
              ('Science of The Total Environment', ''), 
              ('Management Science', 'Management Science'), 
              ('Journal of Biological Chemistry', 'JBC'), 
              ('The Journal of Infectious Diseases', ''), 
              ('Journal of Chemical Information and Modeling', ''), 
              ('meeting of the association for computational linguistics', 'ACL'), 
              ('Physical Review Letters', 'PRL'), 
              ('Physical Review D', 'PRD'), 
              ('The Astrophysical Journal', ''),
              ('Journal of the American Chemical Society', '')
             ]
    cols = ['cos_dist_1950s', 'cos_dist_1960s', 'cos_dist_1970s', 'cos_dist_1980s', 'cos_dist_1990s', 'cos_dist_2000s']
    fig, axes = plt.subplots(3, 5, sharex=True, sharey=True, figsize=(12,8))
    for (v, vb), ax in zip(venues, axes.flatten()):
        vid_dist_df[vid_dist_df.name == v].iloc[0][cols].plot(ax=ax, color='k', ylim=[.1, .6], lw=2, xticks=range(0,6))
        ax.set_title(vb)
    for i in range(5):
        axes[2,i].set(xticklabels=['1950s', '', '1970s', '', '1990s', ''])
    axes[2,2].set(xlabel='Decade')
    axes[1,0].set(ylabel='Cosine distance')
    if save:
        plt.savefig('../figs/journal_dist_align.pdf', bbox_inches='tight')

plot_venue_semantic_change()

# %%
vid_dist_df[][['max_dist', 'total_dist']].corr(method='spearman')
# Out:
#             max_dist  total_dist
# max_dist    1.000000    0.652804
# total_dist  0.652804    1.000000

# %%
vid_dist_df[vid_dist_df.cos_dist_1950s.notna()][['total_dist', 'max_dist']].corr(method='spearman')
# Out:
#             total_dist  max_dist
# total_dist    1.000000  0.759546
# max_dist      0.759546  1.000000

# %%
vid_dist_df[vid_dist_df.cos_dist_1950s.notna()].sort_values('total', ascending=False).total.plot.hist()
# Out:
# <AxesSubplot: ylabel='Frequency'>

# %%
 pd.wide_to_long(vid_dist_df,
                             stubnames=['neighbor_distance'],
                             suffix='.+',
                             sep='_',
                             i = ['vid', 'name'],
                             j = 'decade')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [118], in <cell line: 1>()
# ----> 1 pd.wide_to_long(vid_dist_df,
#       2                             stubnames=['neighbor_distance'],
#       3                             suffix='.+',
#       4                             sep='_',
#       5                             i = ['vid', 'name'],
#       6                             )
#
# TypeError: wide_to_long() missing 1 required positional argument: 'j'
