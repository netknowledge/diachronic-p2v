# %%
# %load_ext autoreload
# %autoreload 1

# %%
import pandas as pd
from pandarallel import pandarallel
import multiprocessing
import numpy as np
import os
from collections import Counter, defaultdict
import itertools
import sys 
sys.path.append("..") 

# %aimport preprocessing
# %aimport utils
# %aimport p2v

from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

from utils import prinT
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

pd.options.display.max_columns = None
pd.set_option('max_colwidth', None)

# %%
from scipy.linalg import orthogonal_procrustes
from sklearn.metrics.pairwise import cosine_similarity, paired_distances

# %%
model = p2v.P2V()
# Out:
# 2023-09-09 11:48:53 -- start loading Mag_venue_info_df
# 2023-09-09 11:48:53 -- finish.
# 2023-09-09 11:48:53 -- start loading labeled_journal_info_df
# 2023-09-09 11:48:53 -- finish.

# %% [markdown]
# # 1. Use the last decade as the reference

# %%
ref_start_year = 2010
ref_end_year = 2021

start_year_list = ['1950', '1960', '1970', '1980', '1990', '2000', '2010']
end_year_list = ['1959', '1969', '1979', '1989', '1999', '2009', '2021']

self_dist_df = pd.DataFrame(columns=['VID'])
for i in range(0, 7):
    tar_start_year = start_year_list[i]
    tar_end_year = end_year_list[i]
    print("-----------------------")
    prinT("start comparing {start_year}-{end_year} with the reference decade".format(start_year=tar_start_year, end_year=tar_end_year))

    tar_wv = model.load_wv(tar_start_year, tar_end_year, 100, 10)
    ref_wv = model.load_wv(ref_start_year, ref_end_year, 100, 10)
    
    tar_VIDs = tar_wv.index_to_key
    ref_VIDs = ref_wv.index_to_key
    shared_VIDs = list(set(tar_VIDs) & set(ref_VIDs))
    prinT("the number of shared VIDs between this two decades: %d" %len(shared_VIDs))
    
    tar_idx = [tar_wv.get_index(VID) for VID in shared_VIDs]
    ref_idx = [ref_wv.get_index(VID) for VID in shared_VIDs]
    
    tar_vectors = tar_wv.get_normed_vectors()[tar_idx]
    ref_vectors = ref_wv.get_normed_vectors()[ref_idx]
    
    prinT("start aligning...")
    R, sca = orthogonal_procrustes(tar_vectors, ref_vectors)
    aligned_tar_vectors = np.dot(tar_vectors, R)
    prinT("finish. start compute cosine distance...")
    # cs = np.diagonal(cosine_similarity(aligned_tar_vectors, ref_vectors))
    dist =  paired_distances(aligned_tar_vectors, ref_vectors, metric='cosine')
    prinT("finish")

    tar_dist_df = pd.DataFrame({'VID': shared_VIDs,
                              'self_distance_'+tar_start_year+'s': dist})
    self_dist_df = self_dist_df.merge(tar_dist_df,
                        on='VID',
                        how='outer')
self_dist_df.loc[:,'venue_name'] = self_dist_df['VID'].apply(lambda x: model.MAG_venue_info_df.at[x, 'OriginalVenue'])
VID_labele_dict = model.load_VID_labeled(ref_start_year, ref_end_year, 100, 10)
self_dist_df['scopus_label'] = self_dist_df.VID.map(lambda x: 
                                          VID_labele_dict['label'][VID_labele_dict['VID'].index(x)] if x in VID_labele_dict['VID']
                                          else np.nan)
# Out:
# -----------------------
# 2023-09-09 17:15:24 -- start comparing 1950-1959 with the reference decade
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (1645, 100)
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:24 -- the number of shared VIDs between this two decades: 1202
# 2023-09-09 17:15:24 -- start aligning...
# 2023-09-09 17:15:24 -- finish. start compute cosine distance...
# 2023-09-09 17:15:24 -- finish
# -----------------------
# 2023-09-09 17:15:24 -- start comparing 1960-1969 with the reference decade
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (3116, 100)
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:24 -- the number of shared VIDs between this two decades: 2351
# 2023-09-09 17:15:24 -- start aligning...
# 2023-09-09 17:15:24 -- finish. start compute cosine distance...
# 2023-09-09 17:15:24 -- finish
# -----------------------
# 2023-09-09 17:15:24 -- start comparing 1970-1979 with the reference decade
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (5686, 100)
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:24 -- the number of shared VIDs between this two decades: 4363
# 2023-09-09 17:15:24 -- start aligning...
# 2023-09-09 17:15:24 -- finish. start compute cosine distance...
# 2023-09-09 17:15:24 -- finish
# -----------------------
# 2023-09-09 17:15:24 -- start comparing 1980-1989 with the reference decade
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (9337, 100)
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:24 -- the number of shared VIDs between this two decades: 7343
# 2023-09-09 17:15:24 -- start aligning...
# 2023-09-09 17:15:24 -- finish. start compute cosine distance...
# 2023-09-09 17:15:24 -- finish
# -----------------------
# 2023-09-09 17:15:24 -- start comparing 1990-1999 with the reference decade
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:24 -- word vectors loaded, and its shape is: (15019, 100)
# 2023-09-09 17:15:24 -- start loading word vectors...
# 2023-09-09 17:15:25 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:25 -- the number of shared VIDs between this two decades: 12214
# 2023-09-09 17:15:25 -- start aligning...
# 2023-09-09 17:15:25 -- finish. start compute cosine distance...
# 2023-09-09 17:15:25 -- finish
# -----------------------
# 2023-09-09 17:15:25 -- start comparing 2000-2009 with the reference decade
# 2023-09-09 17:15:25 -- start loading word vectors...
# 2023-09-09 17:15:25 -- word vectors loaded, and its shape is: (27460, 100)
# 2023-09-09 17:15:25 -- start loading word vectors...
# 2023-09-09 17:15:25 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:25 -- the number of shared VIDs between this two decades: 24250
# 2023-09-09 17:15:25 -- start aligning...
# 2023-09-09 17:15:25 -- finish. start compute cosine distance...
# 2023-09-09 17:15:25 -- finish
# -----------------------
# 2023-09-09 17:15:25 -- start comparing 2010-2021 with the reference decade
# 2023-09-09 17:15:25 -- start loading word vectors...
# 2023-09-09 17:15:25 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:25 -- start loading word vectors...
# 2023-09-09 17:15:25 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:15:25 -- the number of shared VIDs between this two decades: 37594
# 2023-09-09 17:15:25 -- start aligning...
# 2023-09-09 17:15:25 -- finish. start compute cosine distance...
# 2023-09-09 17:15:25 -- finish
# 2023-09-09 17:15:25 -- start loading VID_labeled...
# 2023-09-09 17:15:25 -- finish.

# %% [markdown]
# # 2. Calculate cosine change between every decade and its previous decade

# %%
start_year_list = ['1950', '1960', '1970', '1980', '1990', '2000', '2010']
end_year_list = ['1959', '1969', '1979', '1989', '1999', '2009', '2021']

cs_df = pd.DataFrame(columns=['VID'])
for i in range(1, 7):
    tar_start_year = start_year_list[i]
    tar_end_year = end_year_list[i]
    ref_start_year = start_year_list[i-1]
    ref_end_year = end_year_list[i-1]
    print("-----------------------")
    prinT("start comparing {start_year}-{end_year} with the reference decade".format(start_year=tar_start_year, end_year=tar_end_year))

    tar_wv = model.load_wv(tar_start_year, tar_end_year, 100, 10)
    ref_wv = model.load_wv(ref_start_year, ref_end_year, 100, 10)
    
    tar_VIDs = tar_wv.index_to_key
    ref_VIDs = ref_wv.index_to_key
    shared_VIDs = list(set(tar_VIDs) & set(ref_VIDs))
    prinT("the number of shared VIDs between this two decades: %d" %len(shared_VIDs))
    
    tar_idx = [tar_wv.get_index(VID) for VID in shared_VIDs]
    ref_idx = [ref_wv.get_index(VID) for VID in shared_VIDs]
    
    tar_vectors = tar_wv.get_normed_vectors()[tar_idx]
    ref_vectors = ref_wv.get_normed_vectors()[ref_idx]
    
    prinT("start aligning...")
    R, sca = orthogonal_procrustes(tar_vectors, ref_vectors)
    aligned_tar_vectors = np.dot(tar_vectors, R)
    prinT("finish. start compute cosine change...")
    cs = np.diagonal(cosine_similarity(aligned_tar_vectors, ref_vectors))
    prinT("finish")

    tar_cs_df = pd.DataFrame({'VID': shared_VIDs,
                              'cosine_similarity_'+tar_start_year+'s': cs})
    cs_df = cs_df.merge(tar_cs_df,
                        on='VID',
                        how='outer')
cs_df.loc[:,'venue_name'] = cs_df['VID'].apply(lambda x: model.MAG_venue_info_df.at[x, 'OriginalVenue'])
VID_labele_dict = model.load_VID_labeled(ref_start_year, ref_end_year, 100, 10)
cs_df['scopus_label'] = cs_df.VID.map(lambda x: 
                                          VID_labele_dict['label'][VID_labele_dict['VID'].index(x)] if x in VID_labele_dict['VID']
                                          else np.nan)
# Out:
# -----------------------
# 2023-08-07 11:36:08 -- start comparing 1960-1969 with the reference decade
# 2023-08-07 11:36:08 -- start loading word vectors...
# 2023-08-07 11:36:08 -- word vectors loaded, and its shape is: (3186, 100)
# 2023-08-07 11:36:08 -- start loading word vectors...
# 2023-08-07 11:36:08 -- word vectors loaded, and its shape is: (1683, 100)
# 2023-08-07 11:36:08 -- the number of shared VIDs between this two decades: 1530
# 2023-08-07 11:36:08 -- start aligning...
# 2023-08-07 11:36:08 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:08 -- finish
# -----------------------
# 2023-08-07 11:36:08 -- start comparing 1970-1979 with the reference decade
# 2023-08-07 11:36:08 -- start loading word vectors...
# 2023-08-07 11:36:08 -- word vectors loaded, and its shape is: (5761, 100)
# 2023-08-07 11:36:08 -- start loading word vectors...
# 2023-08-07 11:36:08 -- word vectors loaded, and its shape is: (3186, 100)
# 2023-08-07 11:36:08 -- the number of shared VIDs between this two decades: 2877
# 2023-08-07 11:36:08 -- start aligning...
# 2023-08-07 11:36:08 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:09 -- finish
# -----------------------
# 2023-08-07 11:36:09 -- start comparing 1980-1989 with the reference decade
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (9437, 100)
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (5761, 100)
# 2023-08-07 11:36:09 -- the number of shared VIDs between this two decades: 5211
# 2023-08-07 11:36:09 -- start aligning...
# 2023-08-07 11:36:09 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:09 -- finish
# -----------------------
# 2023-08-07 11:36:09 -- start comparing 1990-1999 with the reference decade
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (15153, 100)
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (9437, 100)
# 2023-08-07 11:36:09 -- the number of shared VIDs between this two decades: 8532
# 2023-08-07 11:36:09 -- start aligning...
# 2023-08-07 11:36:09 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:09 -- finish
# -----------------------
# 2023-08-07 11:36:09 -- start comparing 2000-2009 with the reference decade
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (27604, 100)
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (15153, 100)
# 2023-08-07 11:36:09 -- the number of shared VIDs between this two decades: 13531
# 2023-08-07 11:36:09 -- start aligning...
# 2023-08-07 11:36:09 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:09 -- finish
# -----------------------
# 2023-08-07 11:36:09 -- start comparing 2010-2021 with the reference decade
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (37679, 100)
# 2023-08-07 11:36:09 -- start loading word vectors...
# 2023-08-07 11:36:09 -- word vectors loaded, and its shape is: (27604, 100)
# 2023-08-07 11:36:09 -- the number of shared VIDs between this two decades: 24380
# 2023-08-07 11:36:09 -- start aligning...
# 2023-08-07 11:36:10 -- finish. start compute cosine similarity...
# 2023-08-07 11:36:11 -- finish
# 2023-08-07 11:36:11 -- start loading VID_labeled...
# 2023-08-07 11:36:11 -- finish.

# %%
cs_df
# Out:
#                 VID  cosine_similarity_1950s  cosine_similarity_1960s  \
# 0      1.479803e+08                 0.536453                      NaN
# 1      2.785285e+06                 0.694030                 0.746864
# 2      1.241662e+08                 0.657591                 0.641123
# 3      2.756444e+09                 0.607243                 0.606009
# 4      1.709670e+08                 0.527496                 0.429602
# ...             ...                      ...                      ...
# 24654  2.764439e+09                      NaN                      NaN
# 24655  2.898526e+09                      NaN                      NaN
# 24656  2.010644e+08                      NaN                      NaN
# 24657  1.125908e+08                      NaN                      NaN
# 24658  2.764833e+09                      NaN                      NaN
#
#        cosine_similarity_1970s  cosine_similarity_1980s  \
# 0                          NaN                 0.466951
# 1                     0.743407                 0.810143
# 2                     0.672203                 0.579373
# 3                     0.473114                 0.496372
# 4                     0.612468                 0.744073
# ...                        ...                      ...
# 24654                      NaN                      NaN
# 24655                      NaN                      NaN
# 24656                      NaN                      NaN
# 24657                      NaN                      NaN
# 24658                      NaN                      NaN
#
#        cosine_similarity_1990s  cosine_similarity_2000s  \
# 0                     0.386582                 0.759120
# 1                     0.766487                 0.821322
# 2                     0.709564                 0.707039
# 3                     0.442619                 0.261401
# 4                     0.726447                 0.807329
# ...                        ...                      ...
# 24654                      NaN                 0.719071
# 24655                      NaN                 0.664372
# 24656                      NaN                 0.824514
# 24657                      NaN                 0.726251
# 24658                      NaN                 0.675121
#
#                                                    venue_name  \
# 0                Bulletin De L Academie Nationale De Medecine
# 1                        The Journal of Comparative Neurology
# 2      Quarterly Journal of Mechanics and Applied Mathematics
# 3                               Advances in internal medicine
# 4                            American Journal of Epidemiology
# ...                                                       ...
# 24654                Bulgarian Journal of Veterinary Medicine
# 24655                       EMC - AKOS - Trattato di Medicina
# 24656               European Journal of Preventive Cardiology
# 24657                       Journal of Transport and Land Use
# 24658                           Meditari Accountancy Research
#
#                               scopus_label
# 0                                 Medicine
# 1                             Neuroscience
# 2                              Mathematics
# 3                                      NaN
# 4                                 Medicine
# ...                                    ...
# 24654                           Veterinary
# 24655                                  NaN
# 24656                             Medicine
# 24657                      Social Sciences
# 24658  Business, Management and Accounting
#
# [24659 rows x 9 columns]

# %%
cs_df['mean_cosine_similarity'] = cs_df.drop(['VID'], axis = 1).mean(axis=1, numeric_only=True)

# %%
cs_df[~(cs_df['cosine_similarity_1960s'].isna() | cs_df['scopus_label'].isna())].sort_values(by='mean_cosine_similarity').head(5)
# Out:
#               VID  cosine_similarity_1960s  cosine_similarity_1970s  \
# 1272  203291325.0                 0.386589                 0.259798
# 54     65315170.0                 0.386006                 0.423142
# 17    169320561.0                 0.453169                 0.571671
# 141   196862746.0                 0.499373                 0.508247
# 282     4310451.0                 0.433791                 0.462982
#
#       cosine_similarity_1980s  cosine_similarity_1990s  \
# 1272                 0.475639                 0.464099
# 54                   0.343308                 0.434169
# 17                   0.450756                 0.534741
# 141                  0.475523                 0.420283
# 282                  0.544392                 0.382973
#
#       cosine_similarity_2000s  cosine_similarity_2010s  \
# 1272                 0.481302                 0.321417
# 54                   0.374105                 0.516077
# 17                   0.322900                 0.350789
# 141                  0.373590                 0.439096
# 282                  0.556032                 0.606499
#
#                                                 venue_name  \
# 1272                                    American Scientist
# 54                                               Endeavour
# 17                                     Scientia Forestalis
# 141   Biographical Memoirs of Fellows of the Royal Society
# 282                                             Homeopathy
#
#                               scopus_label  mean_cosine_similarity
# 1272                     Multidisciplinary                0.398140
# 54                     Arts and Humanities                0.412801
# 17    Agricultural and Biological Sciences                0.447338
# 141                               Medicine                0.452685
# 282                               Medicine                0.497778

# %%
cs_df[~cs_df['scopus_label'].isna()].sort_values(by=['cosine_similarity_1960s']).head(20)[['venue_name','scopus_label']]
# Out:
#                                                                  venue_name  \
# 54                                                                Endeavour
# 1272                                                     American Scientist
# 1383                                                Studies in Conservation
# 282                                                              Homeopathy
# 17                                                      Scientia Forestalis
# 665                                    Perspectives in Biology and Medicine
# 788                                             Annual Review of Physiology
# 141                    Biographical Memoirs of Fellows of the Royal Society
# 184                                        Bulletin of Mathematical Biology
# 1020  Journal of The Franklin Institute-engineering and Applied Mathematics
# 408                                             Chemical & Engineering News
# 1201                                Tohoku Journal of Experimental Medicine
# 1501                 Bulletin of the Agricultural Chemical Society of Japan
# 511                                                                   Notes
# 389                                                   California Law Review
# 338                                                    Nippon Kagaku Kaishi
# 1018                 Journal of the History of Medicine and Allied Sciences
# 599                                          School Science and Mathematics
# 723                                             The Imaging Science Journal
# 241                                       Bulletin of The Atomic Scientists
#
#                                       scopus_label
# 54                             Arts and Humanities
# 1272                             Multidisciplinary
# 1383                           Arts and Humanities
# 282                                       Medicine
# 17            Agricultural and Biological Sciences
# 665                                       Medicine
# 788   Biochemistry, Genetics and Molecular Biology
# 141                                       Medicine
# 184   Biochemistry, Genetics and Molecular Biology
# 1020                                   Engineering
# 408                           Chemical Engineering
# 1201                                      Medicine
# 1501  Biochemistry, Genetics and Molecular Biology
# 511                            Arts and Humanities
# 389                                Social Sciences
# 338                                      Chemistry
# 1018                           Arts and Humanities
# 599                                Social Sciences
# 723                               Computer Science
# 241                                Social Sciences

# %%
pd.wide_to_long(cs_df,
                stubnames=['cosine_similarity'],
                suffix='.+',
                sep='_',
                i = ['VID', 'venue_name', 'scopus_label'],
                j = 'decade')
# Out:
#                                                                                             cosine_similarity
# VID          venue_name                                             scopus_label decade
# 1.479803e+08 Bulletin De L Academie Nationale De Medecine           Medicine     1950-1959           0.536453
#                                                                                  1960-1969                NaN
#                                                                                  1970-1979                NaN
#                                                                                  1980-1989           0.466951
#                                                                                  1990-1999           0.386582
# ...                                                                                                       ...
# 2.898264e+09 international conference service robotics technologies NaN          1970-1979                NaN
#                                                                                  1980-1989                NaN
#                                                                                  1990-1999                NaN
#                                                                                  2000-2009                NaN
#                                                                                  2010-2021           1.000000
#
# [263753 rows x 1 columns]

# %%
cs_df_wide = pd.wide_to_long(cs_df,
                             stubnames=['cosine_similarity'],
                             suffix='.+',
                             sep='_',
                             i = ['VID', 'venue_name'],
                             j = 'decade')

plt.figure(dpi=300)
with sns.plotting_context("notebook", font_scale=1.3):
    ax = sns.relplot(data=cs_df_wide,
                     x='decade', y='cosine_similarity',
                     markers=True, dashes=False, style='scopus_label', hue='scopus_label', palette=model.discipline2color,
                     legend=False,
                     col='scopus_label', col_wrap=5, 
                     col_order=['Medicine', 'Social Sciences', 'Arts and Humanities',
                                'Agricultural and Biological Sciences', 'Engineering', 'Mathematics',
                                'Biochemistry, Genetics and Molecular Biology',
                                'Business, Management and Accounting', 'Computer Science',
                                'Earth and Planetary Sciences', 'Economics, Econometrics and Finance',
                                'Psychology', 'Physics and Astronomy', 'Materials Science',
                                'Environmental Science', 'Chemistry',
                                'Pharmacology, Toxicology and Pharmaceutics',
                                'Immunology and Microbiology', 'Nursing', 'Health Professions',
                                'Energy', 'Neuroscience', 'Dentistry', 'Chemical Engineering',
                                'Veterinary', 'Decision Sciences', 'Multidisciplinary'],
                     kind='line')
    ax.set_titles("{col_name}")
    ax.set_ylabels('cosine change')
dirs = '/media/sdb/p2v/figs/'
if not os.path.exists(dirs):
    os.makedirs(dirs)
ax.savefig('/media/sdb/p2v/figs/28_discipline_semantic_change.pdf', 
            dpi = 300, 
            facecolor='white', 
            transparent=False, 
            bbox_inches='tight')

# %% [markdown]
# # 3. Using local neighborhood measure

# %%
def get_tar_avg_neighbor_sim(VID):
    neighbor_sim_list = [tup[1] for tup in tar_wv.most_similar(positive=int(VID), topn=k_list[i])]
    return sum(neighbor_sim_list) / len(neighbor_sim_list)

def get_ref_avg_neighbor_sim(VID):
    neighbor_sim_list = [tup[1] for tup in ref_wv.most_similar(positive=int(VID), topn=k_list[i])]
    return sum(neighbor_sim_list) / len(neighbor_sim_list)

def cal_distance(x):
    neighbor_idx_list = list(set(tar_neighbor_idxs[x]).union(set(ref_neighbor_idxs[x])))
    # tar_neighbor_vectors = [aligned_tar_vectors[idx] for idx in neighbor_idx_list]
    tar_neighbor_vectors = [tar_vectors[idx] for idx in neighbor_idx_list]
    ref_neighbor_vectors = [ref_vectors[idx] for idx in neighbor_idx_list]
    # tar_focal_vector = aligned_tar_vectors[x]
    tar_focal_vector = tar_vectors[x]
    ref_focal_vector = ref_vectors[x]

    tar_second_order_change = cosine_similarity(tar_focal_vector.reshape(1,-1), tar_neighbor_vectors)
    ref_second_order_change = cosine_similarity(ref_focal_vector.reshape(1,-1), ref_neighbor_vectors)

    return paired_distances(tar_second_order_change, ref_second_order_change, metric='cosine')[0]

# %%
k_list = [8, 8, 13, 25, 19, 18, 23]
# k_list = [25, 25, 25, 25, 25, 25]

start_year_list = ['1950', '1960', '1970', '1980', '1990', '2000', '2010']
end_year_list = ['1959', '1969', '1979', '1989', '1999', '2009', '2021']
ref_start_year = 2010
ref_end_year = 2021

neighbor_dist_df = pd.DataFrame(columns=['VID'])
pandarallel.initialize()
for i in range(0, 7):
    tar_start_year = start_year_list[i]
    tar_end_year = end_year_list[i]
    print("-----------------------")
    prinT("start comparing {start_year}-{end_year} with the reference decade".format(start_year=tar_start_year, end_year=tar_end_year))
    
    tar_wv = model.load_wv(tar_start_year, tar_end_year, 100, 10)
    ref_wv = model.load_wv(ref_start_year, ref_end_year, 100, 10)
    
    tar_VIDs = tar_wv.index_to_key
    ref_VIDs = ref_wv.index_to_key
    
    shared_VIDs = list(set(tar_VIDs) & set(ref_VIDs))
    prinT("the number of shared VIDs between this two decades: %d" %len(shared_VIDs))

    # prinT("start filter those periodicals with low neighborhood similarity...")
    # avg_neighbor_sim_df = pd.DataFrame({'VID':shared_VIDs})
    # avg_neighbor_sim_df['tar_avg_neighbor_sim'] = avg_neighbor_sim_df.VID.parallel_apply(get_tar_avg_neighbor_sim)
    # avg_neighbor_sim_df['ref_avg_neighbor_sim'] = avg_neighbor_sim_df.VID.parallel_apply(get_ref_avg_neighbor_sim)
    # shared_VIDs = avg_neighbor_sim_df[(avg_neighbor_sim_df.tar_avg_neighbor_sim >= avg_neighbor_sim_df.tar_avg_neighbor_sim.quantile(0.25)) & 
    #                                   (avg_neighbor_sim_df.ref_avg_neighbor_sim >= avg_neighbor_sim_df.ref_avg_neighbor_sim.quantile(0.25))].VID.tolist()
    
    tar_idx = [tar_wv.get_index(VID) for VID in shared_VIDs]
    ref_idx = [ref_wv.get_index(VID) for VID in shared_VIDs]
    
    tar_vectors = tar_wv.get_normed_vectors()[tar_idx]
    ref_vectors = ref_wv.get_normed_vectors()[ref_idx]
    
    prinT("finish, start generate neighbor union...")
    tar_neighbor_idxs = np.argsort(cosine_similarity(tar_vectors, tar_vectors))[:, -2:-k_list[i]-2:-1]
    ref_neighbor_idxs = np.argsort(cosine_similarity(ref_vectors, ref_vectors))[:, -2:-k_list[-1]-2:-1]
    
    prinT("finish, start calculating local neighborhood change...")
    dist_df = pd.DataFrame({'VID': shared_VIDs})
    dist_df['neighbor_distance_'+tar_start_year+'s'] = dist_df.index.to_series().parallel_apply(cal_distance)
    prinT('finish.')

    neighbor_dist_df = neighbor_dist_df.merge(dist_df, on='VID', how='outer')
    
neighbor_dist_df.loc[:,'venue_name'] = neighbor_dist_df['VID'].apply(lambda x: model.MAG_venue_info_df.at[x, 'OriginalVenue'])
VID_labele_dict = model.load_VID_labeled(ref_start_year, ref_end_year, 100, 10)
neighbor_dist_df['scopus_label'] = neighbor_dist_df.VID.map(lambda x: 
                                          VID_labele_dict['label'][VID_labele_dict['VID'].index(x)] if x in VID_labele_dict['VID']
                                          else np.nan)
# Out:
# INFO: Pandarallel will run on 32 workers.
# INFO: Pandarallel will use Memory file system to transfer data between the main process and workers.
# -----------------------
# 2023-09-09 17:05:00 -- start comparing 1950-1959 with the reference decade
# 2023-09-09 17:05:00 -- start loading word vectors...
# 2023-09-09 17:05:00 -- word vectors loaded, and its shape is: (1645, 100)
# 2023-09-09 17:05:00 -- start loading word vectors...
# 2023-09-09 17:05:00 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:00 -- the number of shared VIDs between this two decades: 1202
# 2023-09-09 17:05:00 -- finish, start generate neighbor union...
# 2023-09-09 17:05:00 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:05:01 -- finish.
# -----------------------
# 2023-09-09 17:05:01 -- start comparing 1960-1969 with the reference decade
# 2023-09-09 17:05:01 -- start loading word vectors...
# 2023-09-09 17:05:01 -- word vectors loaded, and its shape is: (3116, 100)
# 2023-09-09 17:05:01 -- start loading word vectors...
# 2023-09-09 17:05:01 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:01 -- the number of shared VIDs between this two decades: 2351
# 2023-09-09 17:05:01 -- finish, start generate neighbor union...
# 2023-09-09 17:05:02 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:05:03 -- finish.
# -----------------------
# 2023-09-09 17:05:03 -- start comparing 1970-1979 with the reference decade
# 2023-09-09 17:05:03 -- start loading word vectors...
# 2023-09-09 17:05:03 -- word vectors loaded, and its shape is: (5686, 100)
# 2023-09-09 17:05:03 -- start loading word vectors...
# 2023-09-09 17:05:03 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:03 -- the number of shared VIDs between this two decades: 4363
# 2023-09-09 17:05:03 -- finish, start generate neighbor union...
# 2023-09-09 17:05:05 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:05:06 -- finish.
# -----------------------
# 2023-09-09 17:05:06 -- start comparing 1980-1989 with the reference decade
# 2023-09-09 17:05:06 -- start loading word vectors...
# 2023-09-09 17:05:06 -- word vectors loaded, and its shape is: (9337, 100)
# 2023-09-09 17:05:06 -- start loading word vectors...
# 2023-09-09 17:05:06 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:06 -- the number of shared VIDs between this two decades: 7343
# 2023-09-09 17:05:06 -- finish, start generate neighbor union...
# 2023-09-09 17:05:12 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:05:14 -- finish.
# -----------------------
# 2023-09-09 17:05:14 -- start comparing 1990-1999 with the reference decade
# 2023-09-09 17:05:14 -- start loading word vectors...
# 2023-09-09 17:05:14 -- word vectors loaded, and its shape is: (15019, 100)
# 2023-09-09 17:05:14 -- start loading word vectors...
# 2023-09-09 17:05:14 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:14 -- the number of shared VIDs between this two decades: 12214
# 2023-09-09 17:05:14 -- finish, start generate neighbor union...
# 2023-09-09 17:05:32 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:05:33 -- finish.
# -----------------------
# 2023-09-09 17:05:33 -- start comparing 2000-2009 with the reference decade
# 2023-09-09 17:05:33 -- start loading word vectors...
# 2023-09-09 17:05:33 -- word vectors loaded, and its shape is: (27460, 100)
# 2023-09-09 17:05:33 -- start loading word vectors...
# 2023-09-09 17:05:33 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:05:33 -- the number of shared VIDs between this two decades: 24250
# 2023-09-09 17:05:33 -- finish, start generate neighbor union...
# 2023-09-09 17:06:51 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:06:53 -- finish.
# -----------------------
# 2023-09-09 17:06:53 -- start comparing 2010-2021 with the reference decade
# 2023-09-09 17:06:53 -- start loading word vectors...
# 2023-09-09 17:06:53 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:06:53 -- start loading word vectors...
# 2023-09-09 17:06:53 -- word vectors loaded, and its shape is: (37594, 100)
# 2023-09-09 17:06:53 -- the number of shared VIDs between this two decades: 37594
# 2023-09-09 17:06:53 -- finish, start generate neighbor union...
# 2023-09-09 17:10:10 -- finish, start calculating local neighborhood change...
# 2023-09-09 17:10:12 -- finish.
# 2023-09-09 17:10:12 -- start loading VID_labeled...
# 2023-09-09 17:10:12 -- finish.

# %%
overall_dist_df = pd.DataFrame()
overall_dist_df[['VID', 'venue_name', 'scopus_label']] = self_dist_df[['VID', 'venue_name', 'scopus_label']]
overall_dist_df['distance_1950s'] = neighbor_dist_df['neighbor_distance_1950s'] + self_dist_df['self_distance_1950s']
overall_dist_df['distance_1960s'] = neighbor_dist_df['neighbor_distance_1960s'] + self_dist_df['self_distance_1960s']
overall_dist_df['distance_1970s'] = neighbor_dist_df['neighbor_distance_1970s'] + self_dist_df['self_distance_1970s']
overall_dist_df['distance_1980s'] = neighbor_dist_df['neighbor_distance_1980s'] + self_dist_df['self_distance_1980s']
overall_dist_df['distance_1990s'] = neighbor_dist_df['neighbor_distance_1990s'] + self_dist_df['self_distance_1990s']
overall_dist_df['distance_2000s'] = neighbor_dist_df['neighbor_distance_2000s'] + self_dist_df['self_distance_2000s']
overall_dist_df['distance_2010s'] = neighbor_dist_df['neighbor_distance_2010s'] + self_dist_df['self_distance_2010s']

# %%
overall_dist_df
# Out:
#                 VID  \
# 0      1.479803e+08
# 1      1.775432e+08
# 2      2.785285e+06
# 3      2.493381e+09
# 4      1.696707e+08
# ...             ...
# 37589  2.764702e+09
# 37590  4.194223e+06
# 37591  2.764571e+09
# 37592  2.764833e+09
# 37593  2.898264e+09
#
#                                                                                        venue_name  \
# 0                                                    Bulletin De L Academie Nationale De Medecine
# 1                                                                   Michigan Mathematical Journal
# 2                                                            The Journal of Comparative Neurology
# 3                                                         Journal of the Royal Army Medical Corps
# 4                                                                  Wsq: Women's Studies Quarterly
# ...                                                                                           ...
# 37589  Asia-pacific Journal of Multimedia services convergent with Art, Humanities, and Sociology
# 37590                                                     Kuwait Journal of Science & Engineering
# 37591                         International Journal of Multidisciplinary Research and Development
# 37592                                                 Journal of Genetic Syndromes & Gene Therapy
# 37593                                      international conference service robotics technologies
#
#           scopus_label  distance_1950s  distance_1960s  distance_1970s  \
# 0             Medicine        0.501613             NaN             NaN
# 1          Mathematics        0.165739        0.204390        0.263744
# 2         Neuroscience        0.284925        0.292557        0.276899
# 3             Medicine        0.510754        0.474457        0.561197
# 4      Social Sciences        1.174230        1.410990        1.287998
# ...                ...             ...             ...             ...
# 37589              NaN             NaN             NaN             NaN
# 37590              NaN             NaN             NaN             NaN
# 37591              NaN             NaN             NaN             NaN
# 37592              NaN             NaN             NaN             NaN
# 37593              NaN             NaN             NaN             NaN
#
#        distance_1980s  distance_1990s  distance_2000s  distance_2010s
# 0            0.674709        0.737754        0.205929    3.300828e-13
# 1            0.242702        0.274658        0.260853    2.564127e-13
# 2            0.218070        0.239676        0.211894    2.809296e-13
# 3            0.574182        0.418469        0.363855    2.945517e-13
# 4                 NaN             NaN        0.369388    2.324872e-13
# ...               ...             ...             ...             ...
# 37589             NaN             NaN             NaN    3.500321e-13
# 37590             NaN             NaN             NaN    2.481187e-13
# 37591             NaN             NaN             NaN    3.239855e-13
# 37592             NaN             NaN             NaN    3.806162e-13
# 37593             NaN             NaN             NaN    2.953953e-13
#
# [37594 rows x 10 columns]

# %%
overall_dist_df[overall_dist_df.venue_name=='Proceedings of the National Academy of Sciences of the United States of America']
# Out:
#              VID  \
# 624  125754415.0
#
#                                                                           venue_name  \
# 624  Proceedings of the National Academy of Sciences of the United States of America
#
#           scopus_label  distance_1950s  distance_1960s  distance_1970s  \
# 624  Multidisciplinary        0.605732        0.545445        0.460465
#
#      distance_1980s  distance_1990s  distance_2000s  distance_2010s
# 624        0.509767        0.348178         0.26967    3.531074e-13

# %%
overall_dist_df[overall_dist_df.venue_name=='Immunotechnology']
# Out:
#                VID        venue_name                 scopus_label  \
# 11082  172153664.0  Immunotechnology  Immunology and Microbiology
#
#        distance_1950s  distance_1960s  distance_1970s  distance_1980s  \
# 11082             NaN             NaN             NaN             NaN
#
#        distance_1990s  distance_2000s  distance_2010s
# 11082        1.520923         0.56699    3.038313e-13

# %%
overall_dist_df.sort_values(by='distance_1950s', ascending=False).head(20)
# Out:
#                VID  \
# 171   1.901796e+08
# 4     1.696707e+08
# 243   7.789405e+07
# 1095  1.569196e+08
# 210   6.531517e+07
# 61    1.693206e+08
# 426   2.032913e+08
# 692   2.755368e+09
# 701   1.301086e+08
# 896   2.736332e+09
# 144   2.577432e+07
# 72    3.155162e+07
# 491   2.754557e+09
# 1025  3.695378e+07
# 30    1.317008e+08
# 649   1.055018e+08
# 369   1.809803e+08
# 997   4.230722e+07
# 863   4.310451e+06
# 91    5.831286e+07
#
#                                                           venue_name  \
# 171                                 Japanese Journal of Pharmacology
# 4                                     Wsq: Women's Studies Quarterly
# 243                                             Journal of Computers
# 1095                                                 Protein Science
# 210                                                        Endeavour
# 61                                               Scientia Forestalis
# 426                                               American Scientist
# 692                    Journal of the Medical Association of Georgia
# 701                        Journal of the Optical Society of America
# 896                                                      Antibiotics
# 144                                            Juristische Rundschau
# 72                                                         Bioethics
# 491                                                  Modern hospital
# 1025                                                       Tradition
# 30                                          Annals of Human Genetics
# 649   Yakugaku Zasshi-journal of The Pharmaceutical Society of Japan
# 369                                       The Kurume Medical Journal
# 997                              Toxicology and Applied Pharmacology
# 863                                                       Homeopathy
# 91              International Journal of Food Sciences and Nutrition
#
#       distance_1950s  distance_1960s  distance_1970s  distance_1980s  \
# 171         0.690158        0.631299        0.624520        0.733296
# 4           0.601690        0.689180        0.591498             NaN
# 243         0.491499        0.558846        0.491455        0.553426
# 1095        0.462201        0.448470        0.403667        0.295597
# 210         0.456614        0.569566        0.260903        0.368832
# 61          0.451166        0.385416        0.387362        0.146849
# 426         0.450918        0.100594        0.138547        0.208796
# 692         0.429645        0.316017        0.408238        0.293335
# 701         0.408099        0.339749        0.377197        0.357795
# 896         0.385631             NaN             NaN             NaN
# 144         0.370995             NaN        0.325889             NaN
# 72          0.368473             NaN             NaN        0.079846
# 491         0.343309        0.409454        0.422364             NaN
# 1025        0.337873        0.264943        0.368701        0.060172
# 30          0.329533        0.081038        0.081765        0.048095
# 649         0.326830        0.248156        0.192297        0.121277
# 369         0.319392        0.141485        0.075511        0.165119
# 997         0.319124        0.128505        0.041190        0.127004
# 863         0.306899        0.352958        0.268725        0.205124
# 91          0.304925        0.258426        0.169074             NaN
#
#       distance_1990s  distance_2000s  distance_2010s
# 171         0.657449        0.679726             0.0
# 4                NaN        0.024923             0.0
# 243         0.539004        0.034472             0.0
# 1095        0.084390        0.070837             0.0
# 210         0.194836        0.086171             0.0
# 61          0.329635        0.022517             0.0
# 426         0.088024        0.193421             0.0
# 692         0.310374        0.236743             0.0
# 701              NaN        0.201150             0.0
# 896              NaN             NaN             0.0
# 144              NaN             NaN             0.0
# 72          0.039492        0.019588             0.0
# 491              NaN             NaN             0.0
# 1025        0.040128        0.026083             0.0
# 30          0.080774        0.038223             0.0
# 649         0.070437        0.074562             0.0
# 369         0.043414        0.048466             0.0
# 997         0.024724        0.024822             0.0
# 863         0.097424        0.105541             0.0
# 91          0.040477        0.057347             0.0

# %%
def contains(small, big):
    for i in range(len(big)-len(small)+1):
        for j in range(len(small)):
            if big[i+j] != small[j]:
                break
        else:
            return i, i+len(small)
    return False


def cal_slope(x):
    if contains(x[x.notnull()].to_list(), x.to_list()) == False:
        slope = 0
    else:
        try:
            slope = (x[x.notnull()][0] - x[x.notnull()][-1])
        except IndexError:
            slope = 0
    return slope

overall_dist_df.loc[:, 'slope'] = overall_dist_df[['distance_1950s',
                                                   'distance_1960s',
                                                   'distance_1970s',
                                                   'distance_1980s',
                                                   'distance_1990s',
                                                   'distance_2000s']].apply(cal_slope, axis=1)

# %%
overall_dist_df[overall_dist_df.venue_name=='Proceedings of the National Academy of Sciences of the United States of America']
# Out:
#              VID  \
# 624  125754415.0
#
#                                                                           venue_name  \
# 624  Proceedings of the National Academy of Sciences of the United States of America
#
#           scopus_label  distance_1950s  distance_1960s  distance_1970s  \
# 624  Multidisciplinary        0.605732        0.545445        0.460465
#
#      distance_1980s  distance_1990s  distance_2000s  distance_2010s     slope
# 624        0.509767        0.348178         0.26967    3.531074e-13  0.336062

# %%
overall_dist_df[~overall_dist_df.scopus_label.isna()].sort_values(by='slope', ascending=False).head(50)
# Out:
#                 VID  \
# 11082  1.721537e+08
# 5062   2.764708e+09
# 4696   4.273201e+07
# 243    7.789405e+07
# 2002   2.006684e+08
# 4063   1.183154e+08
# 10965  2.079683e+08
# 997    4.230722e+07
# 3089   8.595324e+07
# 7367   1.430634e+08
# 6523   5.986019e+06
# 5537   2.755768e+09
# 6552   8.643183e+07
# 3271   3.666270e+07
# 11247  2.765054e+09
# 2213   2.756091e+09
# 210    6.531517e+07
# 3590   8.954320e+07
# 4019   2.776900e+07
# 3923   6.740156e+07
# 7      1.709670e+08
# 9724   1.199126e+08
# 1313   2.755765e+09
# 4333   9.208579e+07
# 7893   6.245801e+07
# 8391   1.953030e+08
# 11501  1.627521e+08
# 4588   2.036218e+08
# 1095   1.569196e+08
# 968    1.896406e+07
# 666    1.504042e+08
# 2638   1.049241e+08
# 7614   1.716720e+08
# 5810   1.838431e+08
# 1401   6.207222e+07
# 10887  1.208704e+08
# 863    4.310451e+06
# 7076   1.301826e+08
# 2999   9.835552e+07
# 61     1.693206e+08
# 9781   7.806000e+07
# 4683   1.848467e+08
# 1697   9.934778e+07
# 6377   1.313875e+08
# 431    1.009200e+08
# 2725   8.368640e+05
# 2227   7.784729e+07
# 115    5.677253e+06
# 8130   7.012754e+07
# 1025   3.695378e+07
#
#                                                           venue_name  \
# 11082                                               Immunotechnology
# 5062                                              Production Journal
# 4696             Applied Immunohistochemistry & Molecular Morphology
# 243                                             Journal of Computers
# 2002               In Vitro Cellular & Developmental Biology – Plant
# 4063                        The American Journal of Chinese Medicine
# 10965      International Journal on Disability and Human Development
# 997                              Toxicology and Applied Pharmacology
# 3089                               Journal of Biomedical Engineering
# 7367                                                         Insight
# 6523                                                        Database
# 5537               Boletín médico del Hospital Infantil de México
# 6552                                                         English
# 3271                                           Chemistry and Ecology
# 11247                   The Journal of Internet Banking and Commerce
# 2213                   Indian journal of physiology and pharmacology
# 210                                                        Endeavour
# 3590                                                Isa Transactions
# 5537         0.302734    2.511646e-13  0.494340
# 6552         0.405799    2.936867e-13  0.489273
# 3271         0.255717    2.432420e-13  0.484320
# 11247        0.279070    2.391889e-13  0.472326
# 2213         0.280242    2.462668e-13  0.465125
# 210          0.460385    4.012896e-13  0.461527
# 3590         0.235712    3.492686e-13  0.461059
# 4019         0.227169    2.545012e-13  0.438100
# 3923         0.220976    2.026668e-13  0.435504
# 7            0.267551    3.262815e-13  0.419393
# 9724         0.217177    2.960684e-13  0.418689
# 1313         0.295286    2.745819e-13  0.418135
# 4333         0.601553    2.158007e-13  0.411506
# 7893         0.234143    3.571257e-13  0.407085
# 8391         0.292896    3.092384e-13  0.405971
# 11501        0.214534    2.831697e-13  0.405165
# 4588         0.428986    3.029679e-13  0.397067
# 1095         0.333858    3.819125e-13  0.394687
# 968          0.337105    3.029839e-13  0.389629
# 666          0.211574    2.999672e-13  0.388402
# 2638         0.285172    2.826398e-13  0.388288
# 7614         0.247192    3.574945e-13  0.386155
# 5810         0.215705    2.424734e-13  0.386019
# 1401         0.200225    5.632380e-13  0.385691
# 10887        0.241743    2.660450e-13  0.384906
# 863          0.388905    3.195503e-13  0.384870
# 7076         0.189497    1.959026e-13  0.383709
# 2999         0.308041    2.561693e-13  0.380244
# 61           0.606619    2.733677e-13  0.376321
# 9781         0.262772    2.880831e-13  0.374055
# 4683         0.148956    2.615767e-13  0.371731
# 1697         0.326161    2.951665e-13  0.371004
# 6377         0.281208    2.796938e-13  0.370011
# 431          0.225860    4.636988e-13  0.368362
# 2725         0.312114    2.305452e-13  0.367481
# 2227         0.331443    3.881586e-13  0.367175
# 115          0.173155    2.538637e-13  0.365290
# 8130         0.321867    1.927850e-13  0.362302
# 1025         0.268301    2.812521e-13  0.361405

# %%
overall_distance_df_wide = pd.wide_to_long(overall_distance_df,
                             stubnames=['distance'],
                             suffix='.+',
                             sep='_',
                             i = ['VID', 'venue_name'],
                             j = 'decade')

plt.figure(dpi=300)
with sns.plotting_context("notebook", font_scale=1.3):
    ax = sns.relplot(data=overall_distance_df_wide,
                     x='decade', y='distance',
                     markers=True, dashes=False, style='scopus_label', hue='scopus_label', palette=model.discipline2color,
                     legend=False,
                     col='scopus_label', col_wrap=8, 
                     col_order=['Medicine', 'Social Sciences', 'Arts and Humanities',
                                'Agricultural and Biological Sciences', 'Engineering', 'Mathematics',
                                'Biochemistry, Genetics and Molecular Biology',
                                'Business, Management and Accounting', 'Computer Science',
                                'Earth and Planetary Sciences', 'Economics, Econometrics and Finance',
                                'Psychology', 'Physics and Astronomy', 'Materials Science',
                                'Environmental Science', 'Chemistry',
                                'Pharmacology, Toxicology and Pharmaceutics',
                                'Immunology and Microbiology', 'Nursing', 'Health Professions',
                                'Energy', 'Neuroscience', 'Dentistry', 'Chemical Engineering',
                                'Veterinary', 'Decision Sciences', 'Multidisciplinary'],
                     kind='line')
    ax.set_titles("{col_name}")
    ax.set_ylabels('distance')

# %%
dirs = '/media/sdb/p2v/figs/'
if not os.path.exists(dirs):
    os.makedirs(dirs)
ax.savefig('/media/sdb/p2v/figs/28_discipline_semantic_change.pdf', 
            dpi = 300, 
            facecolor='white', 
            transparent=False, 
            bbox_inches='tight')

# %%
periodical_list = ['Science', 'Nature', 
                   'Proceedings of the National Academy of Sciences of the United States of America', 
                   'Journal of Biological Chemistry', 
                                
                   'The Lancet', 'The New England Journal of Medicine', 'JAMA', 'BMJ',
                                
                   'Physical Review Letters', 'The Astrophysical Journal', 'Physical Review D', 
                   'Monthly Notices of the Royal Astronomical Society',

                   'American Sociological Review', 'British Journal of Radiology', 'Journal of the American Chemical Society'
                  ]

overall_distance_df_wide = pd.wide_to_long(overall_distance_df,
                             stubnames=['distance'],
                             suffix='.+',
                             sep='_',
                             i = ['VID', 'venue_name'],
                             j = 'decade')

plt.figure(dpi=300)
with sns.plotting_context("notebook", font_scale=1.3):
    g = sns.relplot(data=overall_distance_df_wide,
                     x='decade', y='distance',
                     legend=False,
                     col='venue_name', col_wrap=5, 
                     col_order=periodical_list,
                     kind='line')
    
    g.set_titles("{col_name}")
    g.axes[2].set_title('PNAS')
    g.set_ylabels('distance')

# %%
dirs = '/media/sdb/p2v/figs/'
if not os.path.exists(dirs):
    os.makedirs(dirs)
g.savefig('/media/sdb/p2v/figs/test.pdf', 
            dpi = 300, 
            facecolor='white', 
            transparent=False, 
            bbox_inches='tight')

# %%
decade_list = ['1950s',
               '1960s',	
               '1970s',	
               '1980s',	
               '1990s',	
               '2000s',
               '2010s']

dist_df = overall_distance_df.copy()
dist_df = dist_df.rename(columns={"distance_1950s": "1950s", 
                                  "distance_1960s": "1960s",
                                  "distance_1970s": "1970s",
                                  "distance_1980s": "1980s",
                                  "distance_1990s": "1990s",
                                  "distance_2000s": "2000s",
                                  "distance_2010s": "2010s"
                                  })

# %%
dist_df
# Out:
#                 VID     1950s     1960s     1970s     1980s     1990s  \
# 0      2.785285e+06  0.034257  0.016690  0.014274  0.009275  0.003836
# 1      1.696707e+08  0.270911  0.539387  0.421861       NaN       NaN
# 2      1.709670e+08  0.124598  0.094019  0.040058  0.022747  0.010806
# 3      1.241662e+08  0.018044  0.029109  0.017825  0.016276  0.018199
# 4      8.802318e+06  0.061019  0.089714  0.154453  0.126062  0.056178
# ...             ...       ...       ...       ...       ...       ...
# 26963  2.764439e+09       NaN       NaN       NaN       NaN       NaN
# 26964  2.898526e+09       NaN       NaN       NaN       NaN       NaN
# 26965  2.764571e+09       NaN       NaN       NaN       NaN       NaN
# 26966  2.764833e+09       NaN       NaN       NaN       NaN       NaN
# 26967  1.125908e+08       NaN       NaN       NaN       NaN       NaN
#
#           2000s  2010s  \
# 0      0.003320    0.0
# 1           NaN    0.0
# 2      0.005647    0.0
# 3      0.005711    0.0
# 4      0.068320    0.0
# ...         ...    ...
# 26963       NaN    0.0
# 26964       NaN    0.0
# 26965       NaN    0.0
# 26966       NaN    0.0
# 26967       NaN    0.0
#
#                                                                 venue_name  \
# 0                                     The Journal of Comparative Neurology
# 1                                           Wsq: Women's Studies Quarterly
# 2                                         American Journal of Epidemiology
# 3                   Quarterly Journal of Mechanics and Applied Mathematics
# 4                               Annals of the New York Academy of Sciences
# ...                                                                    ...
# 26963                             Bulgarian Journal of Veterinary Medicine
# 26964                                    EMC - AKOS - Trattato di Medicina
# 26965  International Journal of Multidisciplinary Research and Development
# 26966                          Journal of Genetic Syndromes & Gene Therapy
# 26967                                    Journal of Transport and Land Use
#
#           scopus_label
# 0         Neuroscience
# 1      Social Sciences
# 2             Medicine
# 3          Mathematics
# 4         Neuroscience
# ...                ...
# 26963       Veterinary
# 26964              NaN
# 26965              NaN
# 26966              NaN
# 26967  Social Sciences
#
# [26968 rows x 10 columns]

# %% [markdown]
# # 3.1 Using change point detection

# %%
def get_z_score_dict(dist_dict):
    """
    Convert the dictionary of distance scores for a given timestep into a dictionary of z-scores - i.e. how many standard deviations is a given word's distance score from the mean of all word's distance scores at this timestep?
    """

    # calculate mean and variance of change scores, ignoring any words for whom the value was None -- calculate the mean and variance of the change scores for all words which are represented in both the current timestep's model and the comparison reference model.
    mean = np.mean(list(dist_dict.values()))
    var = np.var(list(dist_dict.values()))

    z_score_dict = {}
    for VID in dist_dict:
        if var == 0:
            z_score_dict[VID] = 0
        else:
            z_score_dict[VID] = (dist_dict[VID] - mean) / np.sqrt(var)

    return z_score_dict

def compute_mean_shift(time_series_dict, j, compare_to):
	"""
	Compute the mean_shift score at index j of the given time-series.
	"""

	timestep_to_index = {}
	for (i,timestep) in enumerate(sorted(time_series_dict.keys())):
		timestep_to_index[timestep] = i

	xs = list(itertools.chain.from_iterable([timestep_to_index[timestep]]*len(time_series_dict[timestep]) for timestep in time_series_dict))
	ys = list(itertools.chain.from_iterable(time_series_dict.values()))

	
	if compare_to == 'first':
		return np.mean([ys[i] for i in range(len(ys)) if xs[i] > j])  - np.mean([ys[i] for i in range(len(ys)) if xs[i] <= j])
	else: # compare_to == 'last' or compare_to == 'previous':
		return np.mean([ys[i] for i in range(len(ys)) if xs[i] <= j])  - np.mean([ys[i] for i in range(len(ys)) if xs[i] > j])


def get_mean_shift_series(time_series_dict, compare_to):
	"""
	Compute a given word's mean_shift time-series from its time-series of z-scores. 
	"""
	return [compute_mean_shift(time_series_dict, j, compare_to) for j in range(len(time_series_dict.keys())-1)]


def get_p_value_series(word, mean_shift_series, n_samples, z_scores_dict, compare_to):
	"""
	Randomly permute the z-score time series n_samples times, and for each
	permutation, compute the mean-shift time-series of those permuted z-scores, and at each index, check if the mean-shift score from the permuted series is greater than the mean-shift score from the original series. The p-value is the proportion of randomly permuted series which yielded a mean-shift score greater than the original mean-shift score.
	"""
	p_value_series = np.zeros(len(mean_shift_series))
	for i in range(n_samples):
		permuted_z_score_series = np.random.permutation(list(z_scores_dict.values()))
		permuted_z_scores_dict = {}
		for (i,z_scores) in enumerate(permuted_z_score_series):
			permuted_z_scores_dict[i] = z_scores
		mean_shift_permuted_series = get_mean_shift_series(permuted_z_scores_dict, compare_to)

		for x in range(len(mean_shift_permuted_series)):
			if mean_shift_permuted_series[x] > mean_shift_series[x]:
				p_value_series[x] += 1
	p_value_series /= n_samples
	return p_value_series


def detect_change_point(word, z_scores_dict, n_samples, p_value_threshold, gamma_threshold, compare_to):
	"""
	This function computes the mean-shift time-series from the given word's z-score series, then computes the p-value series, 
	"""

	index_to_timestep = {}
	for (i,timestep) in enumerate(sorted(z_scores_dict.keys())):
		index_to_timestep[i] = timestep

	mean_shift_series = get_mean_shift_series(z_scores_dict, compare_to)
	p_value_series = get_p_value_series(word, mean_shift_series, n_samples, z_scores_dict, compare_to)

	# set p-values for any time-slices with average z-scores below gamma threshold to 1, so that these time-slices won't get chosen. 
	for i in range(len(p_value_series)):
		if np.mean(z_scores_dict[index_to_timestep[i]]) < gamma_threshold:
			p_value_series[i] = 1

	# find minimum p_value:
	p_value_series = np.array(p_value_series)
	try:
		min_p_val = p_value_series.min()
	except ValueError:
		print(word)
		print(z_scores_dict)
		print(mean_shift_series)
		print(p_value_series)
    
	# if minimum p_value is below the threshold:
	if min_p_val < p_value_threshold:

		# get indices of time-slices with minimum p_value:
		indices = np.where(p_value_series == min_p_val)[0]

		# as a tie-breaker, return the one which corresponds to the biggest mean_shift
		(change_point, mean_shift) = max([(i, mean_shift_series[i]) for i in indices], key = lambda x:x[1])

		z_score = np.mean(z_scores_dict[index_to_timestep[change_point]])
		time_slice_label = index_to_timestep[change_point]
        
		return (word, time_slice_label, min_p_val, mean_shift, z_score)

	else: 
		return None


def get_word_change_point(tup):
	(word, sim_dict) = tup

	change_point = detect_change_point(word, sim_dict, 
                                       n_samples, p_value_threshold, gamma_threshold, compare_to)
	if change_point:
		return change_point

# %%
i = 0
dict_of_dist_dicts = dist_df.set_index('venue_name')[decade_list[i:]].dropna().to_dict()

# %%
dict_of_z_score_dicts = {}
for t in decade_list[i:]:
    if t in dict_of_dist_dicts:
        dict_of_z_score_dicts[t] = get_z_score_dict(dict_of_dist_dicts[t])

dict_of_dist_by_word = defaultdict(lambda: defaultdict(list))
for time_slice in dict_of_dist_dicts:
    for word in dict_of_dist_dicts[time_slice].keys():
        dict_of_dist_by_word[word][time_slice].append(dict_of_dist_dicts[time_slice][word])

dict_of_z_scores_by_word = defaultdict(lambda: defaultdict(list))
for time_slice in dict_of_z_score_dicts:
    for word in dict_of_z_score_dicts[time_slice].keys():
        dict_of_z_scores_by_word[word][time_slice].append(dict_of_z_score_dicts[time_slice][word])

# %%
len(dict_of_dist_by_word)
# Out:
# 1153

# %%
n_samples = 1000
p_value_threshold = 0.05
gamma_threshold = 0
compare_to = 'last'

# %%
# no standardization

pool = multiprocessing.Pool()
results = pool.map(get_word_change_point, dict_of_dist_by_word.items())
results = [r for r in results if r]

# ranked by mean-shift score first, then by p-value
sorted_results = sorted(results, key=lambda x:-x[3])
sorted_results = sorted(sorted_results, key=lambda x:x[2])

# %%
# with standardization

pool = multiprocessing.Pool()
results = pool.map(get_word_change_point, dict_of_z_scores_by_word.items())
results = [r for r in results if r]

# ranked by mean-shift score first, then by p-value
sorted_results = sorted(results, key=lambda x:-x[3])
sorted_results = sorted(sorted_results, key=lambda x:x[2])
# Out:
# Process ForkPoolWorker-265:
# Process ForkPoolWorker-254:
# Process ForkPoolWorker-252:
# Process ForkPoolWorker-267:
# Process ForkPoolWorker-262:
# Process ForkPoolWorker-269:
# Process ForkPoolWorker-237:
# Process ForkPoolWorker-285:
# Process ForkPoolWorker-244:
# Process ForkPoolWorker-275:
# Process ForkPoolWorker-263:
# Process ForkPoolWorker-281:
# Process ForkPoolWorker-274:
# Process ForkPoolWorker-278:
# Process ForkPoolWorker-241:
# Process ForkPoolWorker-253:
# Process ForkPoolWorker-260:
# Process ForkPoolWorker-286:
# Process ForkPoolWorker-292:
# Process ForkPoolWorker-251:
# Process ForkPoolWorker-250:
# Process ForkPoolWorker-291:
# Process ForkPoolWorker-236:
# Process ForkPoolWorker-282:
# Process ForkPoolWorker-245:
# Process ForkPoolWorker-257:
# Process ForkPoolWorker-249:
# Process ForkPoolWorker-235:
# Traceback (most recent call last):
# Process ForkPoolWorker-261:
# Traceback (most recent call last):
# Process ForkPoolWorker-277:
# Traceback (most recent call last):
# Process ForkPoolWorker-240:
# Process ForkPoolWorker-271:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-268:
# Traceback (most recent call last):
# Process ForkPoolWorker-280:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-287:
# Process ForkPoolWorker-276:
# Process ForkPoolWorker-259:
# Process ForkPoolWorker-255:
# Process ForkPoolWorker-279:
# Traceback (most recent call last):
# Process ForkPoolWorker-294:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-258:
# Process ForkPoolWorker-233:
# Traceback (most recent call last):
# Process ForkPoolWorker-242:
# Process ForkPoolWorker-248:
# Traceback (most recent call last):
# Process ForkPoolWorker-295:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Process ForkPoolWorker-273:
# Process ForkPoolWorker-247:
# Process ForkPoolWorker-246:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-243:
# Process ForkPoolWorker-293:
# Process ForkPoolWorker-284:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-290:
# Process ForkPoolWorker-270:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-264:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-272:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-232:
# Process ForkPoolWorker-234:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-283:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-256:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Process ForkPoolWorker-239:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Process ForkPoolWorker-266:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Process ForkPoolWorker-288:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Process ForkPoolWorker-238:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# Process ForkPoolWorker-289:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 365, in get
#     res = self._reader.recv_bytes()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 414, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/pool.py", line 114, in worker
#     task = get()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
#   File "/usr/lib/python3.10/multiprocessing/queues.py", line 364, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
#   File "/usr/lib/python3.10/multiprocessing/synchronize.py", line 95, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt

# %%
cp_df = pd.DataFrame.from_records(sorted_results, columns =['venue_name', 
                                                            'change_point', 
                                                            'p_value', 
                                                            'mean_shift_score', 
                                                            'z_score'])

# %%
cp_df.head(20)
# Out:
#                                                                          venue_name  \
# 0                                                          British Medical Bulletin
# 1   Proceedings of the National Academy of Sciences of the United States of America
# 2                                                  Zeitschrift für Naturforschung B
# 3                                                               Naturwissenschaften
# 4                                                  American Journal of Epidemiology
# 5                                           International Journal of Legal Medicine
# 6                                                       Immunology and Cell Biology
# 7                    Yakugaku Zasshi-journal of The Pharmaceutical Society of Japan
# 8                                                       Biotechnic & Histochemistry
# 9                           Proceedings of The Royal Society B: Biological Sciences
# 10                                                          Journal of Cell Science
# 11                                             Cellular and Molecular Life Sciences
# 12                                                    Journal of Chemical Education
# 13                                                                    Vox Sanguinis
# 14                                                            Journal of Immunology
# 15                                Philosophical Transactions of the Royal Society B
# 16                                                               Radiation Research
# 17                                          Archives of Physiology and Biochemistry
# 18                                                             Cells Tissues Organs
# 19                                                             Biological Chemistry
#
#    change_point  p_value  mean_shift_score   z_score
# 0         2000s      0.0          4.416168  7.193458
# 1         1950s      0.0          4.044555  5.363306
# 2         1970s      0.0          3.608512  3.497999
# 3         1990s      0.0          3.366414  1.571852
# 4         1960s      0.0          3.235472  3.278905
# 5         1970s      0.0          3.162425  4.763518
# 6         1950s      0.0          3.064426  3.894560
# 7         1990s      0.0          2.952756  2.860176
# 8         2000s      0.0          2.822391  4.007509
# 9         1980s      0.0          2.735662  6.014021
# 10        1960s      0.0          2.599340  2.351634
# 11        1990s      0.0          2.405539  2.591900
# 12        2000s      0.0          2.291206  1.963776
# 13        1960s      0.0          2.225028  2.925288
# 14        1950s      0.0          2.166861  2.374480
# 15        2000s      0.0          2.161881  1.147844
# 16        1950s      0.0          2.089824  2.478633
# 17        2000s      0.0          2.063781  2.004506
# 18        1990s      0.0          1.995927  2.574379
# 19        1950s      0.0          1.988554  2.086167

# %%
def get_neighbor(venue_name):
    VID = model.MAG_venue_info_df[model.MAG_venue_info_df.OriginalVenue==venue_name].index[0]
    tup_list = current_wv.most_similar(positive=VID, topn=3)
    VID_list = [tup[0] for tup in tup_list]
    return [model.MAG_venue_info_df.at[VID, 'OriginalVenue'] for VID in VID_list]

top20_df = cp_df.head(20).copy()

for i in range(0, 7):
    current_wv = model.load_wv(start_year_list[i], end_year_list[i], 100, 10)
    top20_df['neighbor_'+start_year_list[i]+'s'] = top20_df['venue_name'].parallel_apply(get_neighbor)
# Out:
# 2023-09-04 09:27:16 -- start loading word vectors...
# 2023-09-04 09:27:16 -- word vectors loaded, and its shape is: (701, 100)
# 2023-09-04 09:27:17 -- start loading word vectors...
# 2023-09-04 09:27:17 -- word vectors loaded, and its shape is: (1499, 100)
# 2023-09-04 09:27:18 -- start loading word vectors...
# 2023-09-04 09:27:18 -- word vectors loaded, and its shape is: (2942, 100)
# 2023-09-04 09:27:18 -- start loading word vectors...
# 2023-09-04 09:27:18 -- word vectors loaded, and its shape is: (5241, 100)
# 2023-09-04 09:27:19 -- start loading word vectors...
# 2023-09-04 09:27:19 -- word vectors loaded, and its shape is: (9021, 100)
# 2023-09-04 09:27:20 -- start loading word vectors...
# 2023-09-04 09:27:20 -- word vectors loaded, and its shape is: (16449, 100)
# 2023-09-04 09:27:21 -- start loading word vectors...
# 2023-09-04 09:27:21 -- word vectors loaded, and its shape is: (26968, 100)

# %%
top20_df
# Out:
#                                                                          venue_name  \
# 0                                                          British Medical Bulletin
# 1   Proceedings of the National Academy of Sciences of the United States of America
# 2                                                  Zeitschrift für Naturforschung B
# 3                                                               Naturwissenschaften
# 4                                                  American Journal of Epidemiology
# 5                                           International Journal of Legal Medicine
# 6                                                       Immunology and Cell Biology
# 7                    Yakugaku Zasshi-journal of The Pharmaceutical Society of Japan
# 8                                                       Biotechnic & Histochemistry
# 9                           Proceedings of The Royal Society B: Biological Sciences
# 10                                                          Journal of Cell Science
# 11                                             Cellular and Molecular Life Sciences
# 12                                                    Journal of Chemical Education
# 13                                                                    Vox Sanguinis
# 14                                                            Journal of Immunology
# 15                                Philosophical Transactions of the Royal Society B
# 16                                                               Radiation Research
# 17                                          Archives of Physiology and Biochemistry
# 18                                                             Cells Tissues Organs
# 19                                                             Biological Chemistry
# 18  [Journal of Anatomy, Annals of Anatomy-anatomischer Anzeiger, Anatomical Record-advances in Integrative Anatomy and Evolutionary Biology]
# 19                                                      [FEBS Letters, Journal of Biological Chemistry, Cellular and Molecular Life Sciences]
#
#                                                                                                                                                      neighbor_2010s
# 0                                                                               [Revista Chilena de Ortopedia y Traumatología, Medicina-buenos Aires, BMC Medicine]
# 1                                                                                                                [Science Advances, Science, Nature Communications]
# 2                [Journal of Chemical Crystallography, Zeitschrift für anorganische und allgemeine Chemie, Zeitschrift Fur Kristallographie-new Crystal Structures]
# 3                                                                             [Biological Journal of The Linnean Society, Frontiers in Zoology, Journal of Zoology]
# 4                                                                                          [Epidemiology, Annals of Epidemiology, European Journal of Epidemiology]
# 5                                                                            [Legal Medicine, Journal of Forensic Sciences, Journal of Forensic and Legal Medicine]
# 6                                                                                    [Journal of Immunology, Immunological Reviews, European Journal of Immunology]
# 7   [Biological & Pharmaceutical Bulletin, Japanese Journal of Pharmaceutical Health Care and Sciences, Japanese Journal of Complementary and Alternative Medicine]
# 8                                                                               [Journal of Histotechnology, Acta Histochemica, European Journal of Histochemistry]
# 9                                                                                                     [Biology Letters, Journal of Evolutionary Biology, Evolution]
# 10                                                                               [Trends in Cell Biology, Journal of Cell Biology, Current Opinion in Cell Biology]
# 11                                                             [Journal of Biological Chemistry, Biochemical and Biophysical Research Communications, FEBS Letters]
# 12                                                     [Chemistry Education Research and Practice, Biochemistry and Molecular Biology Education, Educación Química]
# 13                                                                                                         [Transfusion, Isbt Science Series, Transfusion Medicine]
# 14                                                                                       [Immunological Reviews, Immunology and Cell Biology, Trends in Immunology]
# 15                                                              [Proceedings of The Royal Society B: Biological Sciences, Biology Letters, The American Naturalist]
# 16                                              [International Journal of Radiation Biology, Radiation and Environmental Biophysics, Journal of Radiation Research]
# 17                                                   [Journal of Physiology and Biochemistry, Metabolism-clinical and Experimental, Experimental Diabetes Research]
# 18                                                 [Tissue Engineering Part A, Journal of Tissue Engineering and Regenerative Medicine, Stem Cells and Development]
# 19                                                                                             [Journal of Biological Chemistry, Biochemical Journal, FEBS Letters]

# %%
def annotate(data, **kws):
    change_point = data.index[0][1]
    mean_shift_score = data.index[0][2]
    p_value = data.index[0][3]
    ax = plt.gca()
    ax.text(.1, .15, f"change point: {change_point}", transform=ax.transAxes)
    ax.text(.1, .10, f"mean shift score: {format((mean_shift_score), '.3f')}", transform=ax.transAxes)
    ax.text(.1, .05, f"p-value: {p_value}", transform=ax.transAxes)

periodical_list = ['Science', 'Nature', 
                   'Proceedings of the National Academy of Sciences of the United States of America', 
                   'Journal of Biological Chemistry', 
                                
                   'The Lancet', 'The New England Journal of Medicine', 'JAMA', 'BMJ',
                   'The American review of respiratory disease',
                                
                   'Physical Review Letters', 'The Astrophysical Journal', 'Physical Review D', 
                   'Monthly Notices of the Royal Astronomical Society',

                   'American Sociological Review',
                   'British Journal of Radiology'
                  ]

overall_distance_df_wide = pd.wide_to_long(cp_df[cp_df.venue_name.isin(periodical_list)].merge(overall_distance_df[overall_distance_df.venue_name.isin(periodical_list)],
                                                    on='venue_name'
                                                   ),
                                                  stubnames=['distance'],
                                                  suffix='.+',
                                                  sep='_',
                                                  i = ['VID', 'change_point', 'mean_shift_score', 'p_value', 'z_score'],
                                                  j = 'decade')

plt.figure(figsize=(40, 30),dpi=300)
with sns.plotting_context("notebook", font_scale=0.7):
    # g = sns.relplot(data=overall_neighbor_change_df_wide,
                     # x='decade', y='local_neighborhood_change',
                     # markers=True, dashes=False, style='venue_name', hue='venue_name',
                     # legend=False,
                     # col='venue_name', col_wrap=5, 
                     # col_order=periodical_list,
                     # kind='line')
    g = sns.FacetGrid(overall_distance_df_wide, col="venue_name", col_wrap=5, col_order=periodical_list)
    g.map_dataframe(sns.lineplot, x='decade', y='distance',
                     markers=True, dashes=False, style='venue_name', hue='venue_name',
                     legend=False,)
    g.map_dataframe(annotate)
    g.set_titles("{col_name}")
    g.axes[2].set_title('PNAS')
    # ax.axes[12].set_title('ACL')
    g.set_ylabels('distance')

plt.show()

# %%
dirs = '/media/sdb/p2v/figs/'
if not os.path.exists(dirs):
    os.makedirs(dirs)
g.savefig('/media/sdb/p2v/figs/change_point.pdf', 
            dpi = 300, 
            facecolor='white', 
            transparent=False, 
            bbox_inches='tight')

# %% [markdown]
# # 3.2 decade by decade

# %%
def get_old_neighbor(venue_name):
    VID = model.MAG_venue_info_df[model.MAG_venue_info_df.OriginalVenue==venue_name].index[0]
    tup_list = old_wv.most_similar(positive=VID, topn=k_list[i])
    VID_list = [tup[0] for tup in tup_list]
    return [model.MAG_venue_info_df.at[VID, 'OriginalVenue'] for VID in VID_list]
def get_new_neighbor(venue_name):
    VID = model.MAG_venue_info_df[model.MAG_venue_info_df.OriginalVenue==venue_name].index[0]
    tup_list = new_wv.most_similar(positive=VID, topn=k_list[i+1])
    VID_list = [tup[0] for tup in tup_list]
    return [model.MAG_venue_info_df.at[VID, 'OriginalVenue'] for VID in VID_list]
def get_old_res_neighbor(x):
    res_neighbor_list = [neighbor for neighbor in x['neighbor_'+start_year_list[i]+'s'] 
                         if neighbor not in x['neighbor_'+start_year_list[i+1]+'s']]
    return res_neighbor_list[0:3]
def get_new_res_neighbor(x):
    res_neighbor_list = [neighbor for neighbor in x['neighbor_'+start_year_list[i+1]+'s'] 
                         if neighbor not in x['neighbor_'+start_year_list[i]+'s']]
    return res_neighbor_list[0:3]

k_list = [5, 7, 14, 17, 9, 17, 28]

for i in range (0, 6):
    old_wv = model.load_wv(start_year_list[i], end_year_list[i], 100, 10)
    new_wv = model.load_wv(start_year_list[i+1], end_year_list[i+1], 100, 10)
    
    intersection_df = dist_df[['VID',start_year_list[i]+'s', start_year_list[i+1]+'s', 'venue_name', 'scopus_label']].dropna()
    intersection_df['difference'] = intersection_df[start_year_list[i]+'s'] - intersection_df[start_year_list[i+1]+'s']
    
    intersection_df['neighbor_'+start_year_list[i]+'s'] = intersection_df['venue_name'].parallel_apply(get_old_neighbor)
    intersection_df['neighbor_'+start_year_list[i+1]+'s'] = intersection_df['venue_name'].parallel_apply(get_new_neighbor)
    
    intersection_df['res_neighbor_'+start_year_list[i]+'s'] = intersection_df.parallel_apply(get_old_res_neighbor, axis=1)
    intersection_df['res_neighbor_'+start_year_list[i+1]+'s'] = intersection_df.parallel_apply(get_new_res_neighbor, axis=1)
    
    display(intersection_df.sort_values('difference', ascending=False).head(10)[['venue_name', 
                                                                                 'scopus_label', 
                                                                                 'difference',
                                                                                 'res_neighbor_'+start_year_list[i]+'s',
                                                                                 'res_neighbor_'+start_year_list[i+1]+'s'
                                                                                ]])
# Out:
# 2023-09-05 14:00:23 -- start loading word vectors...
# 2023-09-05 14:00:23 -- word vectors loaded, and its shape is: (701, 100)
# 2023-09-05 14:00:23 -- start loading word vectors...
# 2023-09-05 14:00:23 -- word vectors loaded, and its shape is: (1499, 100)
#                                                                           venue_name  \
# 279  Proceedings of the National Academy of Sciences of the United States of America
# 249                                                               Radiation Research
# 543                                                      Immunology and Cell Biology
# 313                                            European Food Research and Technology
# 534                            Journal of Pharmacology and Experimental Therapeutics
# 513                                     Journal of the Acoustical Society of America
# 178                                              Deutsche Medizinische Wochenschrift
# 417                                                             Clinica Chimica Acta
# 49                                           Archives of Physiology and Biochemistry
# 541                                                              Naturwissenschaften
#
#                                      scopus_label  difference  \
# 279                             Multidisciplinary    0.089846
# 249                                      Medicine    0.066169
# 543                   Immunology and Microbiology    0.055319
# 313          Agricultural and Biological Sciences    0.054082
# 534    Pharmacology, Toxicology and Pharmaceutics    0.050531
# 513                         Physics and Astronomy    0.049465
# 178                                      Medicine    0.049013
# 417  Biochemistry, Genetics and Molecular Biology    0.048523
# 49                                       Medicine    0.048275
# 541          Agricultural and Biological Sciences    0.047407
#
#                                                                                                                                  res_neighbor_1950s  \
# 279                                                            [Annals of Mathematics, Nagoya Mathematical Journal, Journal D Analyse Mathematique]
# 249  [Journal of Cellular and Comparative Physiology, The International Journal of Applied Radiation and Isotopes, Physics in Medicine and Biology]
# 543                                                                                              [Veterinary Record, Annales de l'Institut Pasteur]
# 313                                        [Biological Chemistry, Macromolecular Chemistry and Physics, Journal of Agricultural and Food Chemistry]
# 534                                                                          [Anesthesia & Analgesia, Anesthesiology, A.M.A. archives of pathology]
# 513                                                           [Annales Des Télécommunications, IEEE Transactions on Information Theory, Geophysics]
# 178                                                                                                                          [Biological Chemistry]
# 417                                                                      [Methods in Enzymology, Annals of Hematology, Journal of Chromatography A]
# 49                            [Journal of Insect Physiology, Psychiatry and Clinical Neurosciences, Journal of Cellular and Comparative Physiology]
# 541                                                                                                   [Journal of Plant Nutrition and Soil Science]
#
#                                                                                                                                     res_neighbor_1960s
# 279                             [Progress in Nucleic Acid Research and Molecular Biology, Journal of Molecular Biology, Michigan Mathematical Journal]
# 249                                        [International Journal of Radiation Biology, Advances in biological and medical physics, Mutation Research]
# 543                                   [Australian Journal of Zoology, International Archives of Allergy and Immunology, Australian Veterinary Journal]
# 313                                       [Advances in food research, Plant Foods for Human Nutrition, Journal of the Science of Food and Agriculture]
# 534  [Archives internationales de pharmacodynamie et de thérapie, Clinical Pharmacology & Therapeutics, Naunyn-schmiedebergs Archives of Pharmacology]
# 513                                    [Journal of Speech Language and Hearing Research, Journal of Applied Mechanics, Journal of Sound and Vibration]
# 178                                                                                            [Medizinische Klinik, Medizinische Welt, Drug Research]
# 417                                                          [Clinical Chemistry, Clinical Chemistry and Laboratory Medicine, Analytical Biochemistry]
# 49                                                      [Japanese Journal of Physiology, Bulletin of Experimental Biology and Medicine, Life Sciences]
# 541                                                                                      [Planta Medica, Cellular and Molecular Life Sciences, Planta]
# 2023-09-05 14:00:49 -- start loading word vectors...
# 2023-09-05 14:00:49 -- word vectors loaded, and its shape is: (1499, 100)
# 2023-09-05 14:00:49 -- start loading word vectors...
# 2023-09-05 14:00:49 -- word vectors loaded, and its shape is: (2942, 100)
#                             venue_name  \
# 1       Wsq: Women's Studies Quarterly
# 688               Journal of Computers
# 665                          Endeavour
# 815                        Cryobiology
# 994                         BioSystems
# 804     IEEE Transactions on Education
# 498                Scientific American
# 2     American Journal of Epidemiology
# 1087                      Pathobiology
# 50             Journal of Cell Science
#
#                                       scopus_label  difference  \
# 1                                  Social Sciences    0.117526
# 688                               Computer Science    0.105501
# 665                            Arts and Humanities    0.087282
# 815                                       Medicine    0.077253
# 994                                    Mathematics    0.073771
# 804                                Social Sciences    0.072200
# 498                              Multidisciplinary    0.056835
# 2                                         Medicine    0.053960
# 1087                                      Medicine    0.053328
# 50    Biochemistry, Genetics and Molecular Biology    0.052201
#
#                                                                                                                                   res_neighbor_1960s  \
# 1                                                   [New Zealand Journal of Marine and Freshwater Research, Ices Journal of Marine Science, Ophelia]
# 688                            [Annual Review of Physical Chemistry, Journal of Polymer Science Part B: Polymer Letters, Journal of Polymer Science]
# 665                                                                                          [Plant and Cell Physiology, Tetrahedron, Planta Medica]
# 815                                     [Advances in Applied Microbiology, Journal of Biomedical Materials Research, Journal of Cellular Physiology]
# 994   [Journal of Cellular Physiology, Biochemical and Biophysical Research Communications, Progress in Nucleic Acid Research and Molecular Biology]
# 804                    [IEEE Transactions on Aerospace and Electronic Systems, IEEE Transactions on Aerospace, IEEE Journal of Solid-state Circuits]
# 498                                                                                        [Technology and Culture, Geographical Review, Geriatrics]
# 2                                                                   [Acta Virologica, Journal of Immunology, A.M.A. journal of diseases of children]
# 1087                                                                            [Pharmacology, Deutsche Medizinische Wochenschrift, Presse Medicale]
# 50                                                      [Cell and Tissue Research, Journal of Morphology, Zoological Journal of the Linnean Society]
#
#                                                                                                                          res_neighbor_1970s
# 1                                                [The Progressive Fish-culturist, Journal of Fish Biology, Environmental Biology of Fishes]
# 688   [Journal of the Chemical Society, Faraday Transactions, Chemical Society Reviews, Collection of Czechoslovak Chemical Communications]
# 665                                     [Bulletin De La Societe Geologique De France, Grana, International Journal of Nautical Archaeology]
# 815                                              [Cryogenics, Journal of Thermal Biology, The Journal of Dermatologic Surgery and Oncology]
# 994                     [Origins of Life and Evolution of Biospheres, Molecular and Cellular Biochemistry, Plant Systematics and Evolution]
# 804        [Innovations in Education and Training International, Improving College and University Teaching, Educational Technology archive]
# 498                                                                                     [Minerva, Psyccritiques, Social Studies of Science]
# 2                                                [International Journal of Epidemiology, HSMHA health reports, Journal of Chronic Diseases]
# 1087                               [The Japanese journal of experimental medicine, American Journal of Pathology, Laboratory Investigation]
# 50                                                                         [Developmental Biology, Experimental Cell Research, Protoplasma]
# 2023-09-05 14:01:30 -- start loading word vectors...
# 2023-09-05 14:01:30 -- word vectors loaded, and its shape is: (2942, 100)
# 2023-09-05 14:01:30 -- start loading word vectors...
# 2023-09-05 14:01:30 -- word vectors loaded, and its shape is: (5241, 100)
#                                       venue_name           scopus_label  \
# 1105      Radiation and Environmental Biophysics               Medicine
# 1406                            Physical Therapy     Health Professions
# 473             Zeitschrift für Naturforschung B              Chemistry
# 508               Physica D: Nonlinear Phenomena  Physics and Astronomy
# 840   Chemistry and Technology of Fuels and Oils                 Energy
# 382                 Optometry and Vision Science               Medicine
# 687                                  Ultrasonics  Physics and Astronomy
# 2316                        Computers & Graphics       Computer Science
# 1390                                 Gerontology               Medicine
# 518      International Journal of Legal Medicine               Medicine
#
#       difference  \
# 1105    0.070230
# 1406    0.068728
# 473     0.066947
# 508     0.063709
# 840     0.063638
# 382     0.051595
# 687     0.049877
# 2316    0.041965
# 1390    0.041397
# 518     0.041083
#
#                                                                                                                                                                                             res_neighbor_1970s  \
# 1105                                                                                                                                  [Biophysical Journal, The Journal of Membrane Biology, Radiation Botany]
# 1406                                                                                                           [New York state journal of medicine, Southern Medical Journal, Dental Clinics of North America]
# 473                                                                                                                    [Naturwissenschaften, European Journal of Organic Chemistry, Plant and Cell Physiology]
# 508                                                                                                      [Physica B-condensed Matter, Physica A-statistical Mechanics and Its Applications, Physical Review A]
# 840                                                                                                                                       [Polymer Science U.s.s.r., Tribology International, Fibre Chemistry]
# 382   [Transactions. Section on Ophthalmology. American Academy of Ophthalmology and Otolaryngology, The Australian Journal of Optometry, Transactions - American Academy of Ophthalmology and Otolaryngology]
# 687                                                                                                                              [Non-destructive Testing, Journal of Clinical Ultrasound, Physical Acoustics]
# 2316                                                                                                   [design automation conference, Advances in Computers, international symposium on computer architecture]
# 1390                                                                                                                                           [Physiological Research, Laboratory Investigation, Biomedicine]
# 518                                                                                                                     [Forensic Science, Zeitschrift für Immunitätsforschung: Immunobiology, Human Genetics]
#
#                                                                                                                                        res_neighbor_1980s
# 1105                                                [Advances in radiation biology, Journal of Radiation Research, International Journal of Hyperthermia]
# 1406                                [Journal of Orthopaedic & Sports Physical Therapy, Clinical Rehabilitation, Occupational Therapy Journal of Research]
# 473                                                         [Inorganic Chemistry, Angewandte Chemie, Journal of The Chemical Society-dalton Transactions]
# 508                                          [Japan Journal of Applied Mathematics, Journal of Statistical Physics, Publications Mathématiques de l'IHÉS]
# 840                                              [Petroleum Science and Technology, Fuel Processing Technology, Journal of The Japan Petroleum Institute]
# 382                           [Ophthalmic and Physiological Optics, Journal of The British Contact Lens Association, Clinical and Experimental Optometry]
# 687   [IEEE Transactions on Ultrasonics Ferroelectrics and Frequency Control, international symposium on electrets, Journal of Nondestructive Evaluation]
# 2316                                                                                         [The Visual Computer, eurographics, Computer Graphics Forum]
# 1390                                                 [Age and Ageing, Archives of Gerontology and Geriatrics, Journal of the American Geriatrics Society]
