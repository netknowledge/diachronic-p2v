# %%
# %load_ext autoreload
# %autoreload 1

# %%
import sys 
sys.path.append("diachronic-p2v") 
# %aimport p2v

# %%
model = p2v.P2V()
# Out:
# data_dir:  /mnt/d/projects/diachronic-p2v/data
# 2024-11-13 15:43:20 -- start loading Mag_venue_info_df
# 2024-11-13 15:43:20 -- finish.
# 2024-11-13 15:43:20 -- start loading labeled_journal_info_df
# 2024-11-13 15:43:20 -- finish.

# %%
model.plot_map_of_sci(1950,1959, 100, 10, 
                      y_flip=False, rotate_90=False, 
                      save_fig=True)
# Out:
# 2024-11-13 16:12:56 -- start loading VID_labeled...
# 2024-11-13 16:12:56 -- finish.
# 2024-11-13 16:12:56 -- start loading wv_2d...
# 2024-11-13 16:12:56 -- finish.
# 2024-11-13 16:12:57 -- 1253 journals' map of sci fig for 1950 to 1959 saved to file!

# %%
model.plot_map_of_sci(1960,1969, 100, 10, 
                      y_flip=True,
                      save_fig=True)
# Out:
# 2024-11-13 16:13:02 -- start loading VID_labeled...
# 2024-11-13 16:13:02 -- finish.
# 2024-11-13 16:13:02 -- start loading wv_2d...
# 2024-11-13 16:13:02 -- finish.
# 2024-11-13 16:13:02 -- 2378 journals' map of sci fig for 1960 to 1969 saved to file!

# %%
model.plot_map_of_sci(1970,1979, 100, 10, 
                      y_flip=True, 
                      save_fig=True)
# Out:
# 2024-11-13 16:13:05 -- start loading VID_labeled...
# 2024-11-13 16:13:05 -- finish.
# 2024-11-13 16:13:05 -- start loading wv_2d...
# 2024-11-13 16:13:05 -- finish.
# 2024-11-13 16:13:05 -- 4277 journals' map of sci fig for 1970 to 1979 saved to file!

# %%
model.plot_map_of_sci(1980,1989, 100, 10, 
                      y_flip=True, 
                      # rotate_90_clockwise=True, 
                      save_fig=True)
# Out:
# 2024-11-13 16:13:07 -- start loading VID_labeled...
# 2024-11-13 16:13:07 -- finish.
# 2024-11-13 16:13:07 -- start loading wv_2d...
# 2024-11-13 16:13:07 -- finish.
# 2024-11-13 16:13:07 -- 6889 journals' map of sci fig for 1980 to 1989 saved to file!

# %%
model.plot_map_of_sci(1990,1999, 100, 10, 
                      # y_flip=False, rotate_90_clockwise=True, 
                      save_fig=True)
# Out:
# 2024-11-13 16:13:10 -- start loading VID_labeled...
# 2024-11-13 16:13:10 -- finish.
# 2024-11-13 16:13:10 -- start loading wv_2d...
# 2024-11-13 16:13:10 -- finish.
# 2024-11-13 16:13:10 -- 10600 journals' map of sci fig for 1990 to 1999 saved to file!

# %%
model.plot_map_of_sci(2000,2009, 100, 10, 
                      # y_flip=True, rotate_180=True, 
                      save_fig=True)
# Out:
# 2024-11-13 16:13:13 -- start loading VID_labeled...
# 2024-11-13 16:13:13 -- finish.
# 2024-11-13 16:13:13 -- start loading wv_2d...
# 2024-11-13 16:13:13 -- finish.
# 2024-11-13 16:13:13 -- 17043 journals' map of sci fig for 2000 to 2009 saved to file!

# %%
plot_df = model.plot_map_of_sci(2010,2021, 100, 10,
                                #y_flip=False, rotate_180=False, 
                                save_fig=True)
# Out:
# 2024-11-13 16:13:16 -- start loading VID_labeled...
# 2024-11-13 16:13:16 -- finish.
# 2024-11-13 16:13:16 -- start loading wv_2d...
# 2024-11-13 16:13:16 -- finish.
# 2024-11-13 16:13:17 -- 20038 journals' map of sci fig for 2010 to 2021 saved to file!
